# %%
# -*- coding: utf-8 -*-

import os
import pandas as pd
import numpy as np
from collections import Counter
import nltk
from nltk import sent_tokenize, word_tokenize
from string import punctuation
import string
from nltk.corpus import stopwords
stop = set(stopwords.words('russian'))
# from nltk.stem import SnowballStemmer
from collections import Counter
# stemmer = SnowballStemmer('russian')
import os
import re


from random import shuffle

from libs.utils import preprocessing, preprocessing_2, convert_float
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload

# %autoreload 2

# %% [markdown]
# ## Data Preparation

# %%
col_type={'_id': str,
       'cont_num':str,
       'sign_date':str,
       'custom_regnum':str,
       'product_name':str,
       'okdp_code':str,
       'okei_code':str,
       'quantity':float,
       'price':float,
       'sum':float
       }

df = pd.read_csv('datascript/medical_2012_fulldata.csv', sep=';',dtype=col_type)
df.head()
# Out:
#          _id             cont_num   sign_date custom_regnum  \
# 0  1133680_0  0321300036512000008  2012-04-03   03213000365
# 1   12192474  0321300168013000051  2012-11-14   03213001680
# 2   12798155  0356300059112000002  2012-01-03   03563000591
# 3   12798156  0356300059112000002  2012-01-03   03563000591
# 4   12798157  0356300059112000002  2012-01-03   03563000591
#
#                                         product_name okdp_code okei_code  \
# 0                                    Медикаменты\r\n   2423684       796
# 1  Средства тормозящие свертывание крови (средств...   2423253       778
# 2               Натрия о-йодгиппурат, 131-I (40 МБк)   2423960       704
# 3       Тиреотропный гормон ИРМА для 400 определений   2423960       704
# 4        Общий трийодтиронин РИА для 100 определений   2423960       704
#
#    quantity      price        sum
# 0       1.0  488491.41  488491.41
# 1      10.0    5160.00   51600.00
# 2      42.0   16224.74  681439.08
# 3       7.0   15451.00  108157.00
# 4      12.0    3078.00   36936.00

# %%
len(df)
# Out:
# 2168870

# %% [markdown]
# ## Countries

# %%
import pandas as pd
data_xls = pd.read_excel('data/countries.xls', 'grls2', index_col=0)
# data_xls.to_csv('countries.csv', encoding='utf-8')

data_xls.drop('Номер регистрационного удостоверения', inplace=True)

countries = set([x.lower() for x in data_xls['Unnamed: 6'] if (isinstance(x, str) and x[0] != ' ')])
countries.remove('~')
countries
# Out:
# {'австралия',
#  'австрия',
#  'азербайджан',
#  'аргентина',
#  'армения',
#  'беларусь',
#  'бельгия',
#  'болгария',
#  'босния и герцеговина',
#  'бразилия',
#  'британские виргинские острова',
#  'великобритания',
#  'венгрия',
#  'вьетнам',
#  'германия',
#  'гонконг (кнр)',
#  'греция',
#  'грузия',
#  'дания',
#  'египет',
#  'израиль',
#  'индия',
#  'индонезия',
#  'иордания',
#  'иран',
#  'ирландия',
#  'исландия',
#  'испания',
#  'италия',
#  'казахстан',
#  'канада',
#  'кипр',
#  'китай',
#  'кнр',
#  'корея',
#  'корея южная',
#  'куба',
#  'кыргызская республика',
#  'латвия',
#  'литва',
#  'лихтенштейн',
#  'люксембург',
#  'малайзия',
#  'мальта',
#  'мексика',
#  'нидерландские антилы',
#  'нидерланды',
#  'новая зеландия',
#  'норвегия',
#  'объединенные арабские эмираты',
#  'оман',
#  'пакистан',
#  'панама',
#  'перу',
#  'польша',
#  'португалия',
#  'пуэрто-рико',
#  'пуэрто-рико (сша)',
#  'пуэрто-рико, сша',
#  'республика беларусь',
#  'республика болгария',
#  'республика казахстан',
#  'республика корея',
#  'республика куба',
#  'республика маврикий',
#  'республика македония',
#  'республика молдова',
#  'республика северная македония',
#  'республика сейшельские острова',
#  'республика сербия',
#  'республика хорватия',
#  'республика эстония',
#  'росси',
#  'россии',
#  'россия',
#  'румыния',
#  'саудовская аравия',
#  'сербия',
#  'сербия и черногория',
#  'сингапур',
#  'сирия',
#  'словакия',
#  'словацкая республика',
#  'словения',
#  'соединенное королевство',
#  'соединенные штаты',
#  'сша',
#  'таиланд',
#  'тайвань, китайская республика',
#  'тунис',
#  'турция',
#  'узбекистан',
#  'украина',
#  'финляндия',
#  'франция',
#  'фрг',
#  'хорватия',
#  'черногория',
#  'чехия',
#  'чешская республика',
#  'швейцари',
#  'швейцария',
#  'швеция',
#  'шотландия',
#  'эстония',
#  'эстонская республика',
#  'юар',
#  'югославия',
#  'япония'}

# %%
def check_country(s):
    for c in countries:
        if c in str(s):
            return c
    return pd.np.nan

df['country'] = df['product_name'].apply(lambda x : check_country(x))

# %%
df.columns
# Out:
# Index(['_id', 'cont_num', 'sign_date', 'custom_regnum', 'product_name',
#        'okdp_code', 'okei_code', 'quantity', 'price', 'sum', 'country'],
#       dtype='object')

# %% [markdown]
# ## List of all pharma names

# %%
data_ff = data_xls[['Unnamed: 7', 'Unnamed: 9']]

data_ff.reset_index(inplace=True, drop=True)
data_ff['trade'] = data_ff['Unnamed: 7']
data_ff['official'] = data_ff['Unnamed: 9']
data_ff.drop(['Unnamed: 7', 'Unnamed: 9'], axis=1, inplace=True)
data_ff.head(30)
import re
delimiters = '®', '(',')', '~', '-', ':', '.', ',', '№', '+', '[',']', '{', '}', ' '
# example = "stackoverflow (c) is awesome... isn't it?"
regexPattern = '|'.join(map(re.escape, delimiters))
trade_to_official_dic = dict()
for trade_name, official_name in zip(list(data_ff['trade']), list(data_ff['official'])):
    if (isinstance(trade_name, float) or isinstance(official_name, float)):
        continue
    trades = re.split(regexPattern, trade_name)
    officials = re.split(regexPattern, official_name)
    max_word_trade = ''
    for trade in trades:
        if len(trade) > len(max_word_trade):
            max_word_trade = trade
    max_word_official = ''
    for official in officials:
        if len(official) > len(max_word_official):
            max_word_official = official
    trade_to_official_dic[max_word_trade] = max_word_official

# re.split(regexPattern, example)

#processing
data_ff['trade'] = data_ff['trade'].apply(lambda x : str(x).lower())
data_ff['official'] = data_ff['official'].apply(lambda x : str(x).lower())
delimiters = '®', '(',')', '~', '-', ':', '.', ',', '№', '+', '[',']', '{', '}', ' '
data_ff['official']=data_ff['official'].map(lambda x: re.sub('\d+', '',str(x)))
data_ff['trade']=data_ff['trade'].map(lambda x: re.sub('\d+', '',str(x)))
data_ff['trade']=data_ff['trade'].apply(lambda x: re.split(regexPattern, str(x)))
data_ff['official']=data_ff['official'].apply(lambda x: re.split(regexPattern, str(x)))
data_ff['official']=data_ff['official'].map(lambda x: [z for z in x if z != ''])
data_ff['trade']=data_ff['trade'].map(lambda x: [z for z in x if z != ''])

from tqdm import tqdm

set_of_meds = set()
for i in tqdm(range(len(data_ff))):
    for w in data_ff.loc[i, 'trade']:
        set_of_meds.add(w)
    for w in data_ff.loc[i, 'official']:
        set_of_meds.add(w)
# Out:
# 100%|██████████| 61605/61605 [00:00<00:00, 76910.10it/s]

# %%
str(None)
# Out:
# 'None'

# %%
### Preprocessing
df['product_name'] = df['product_name'].astype(str)
df = preprocessing(df)
df = preprocessing_2(df)
df.reset_index(inplace=True, drop=True)

# %%
len(df)
# Out:
# 2096059

# %% [markdown]
# # SUM

# %%
df_old = pd.read_csv('datascript/medical_2012_fulldata.csv', sep=';',dtype=col_type)
print(df['sum'].astype('float32').sum()/df_old['sum'].astype('float32').sum())
# Out:
# 0.88313156

# %%
df.head()
# Out:
#          _id                                       product_name  quantity  \
# 0  1133680_0                                    Медикаменты\r\n       1.0
# 1   12192474  Средства тормозящие свертывание крови (средств...      10.0
# 2   12798155               Натрия о-йодгиппурат, 131-I (40 МБк)      42.0
# 3   12798156       Тиреотропный гормон ИРМА для 400 определений       7.0
# 4   12798157        Общий трийодтиронин РИА для 100 определений      12.0
#
#        price        sum country  \
# 0  488491.41  488491.41     NaN
# 1    5160.00   51600.00     NaN
# 2   16224.74  681439.08     NaN
# 3   15451.00  108157.00     NaN
# 4    3078.00   36936.00     NaN
#
#                                            name_norm  mg_ml  ml  mg   g  \
# 0                                    медикаменты\r\n    NaN NaN NaN NaN
# 1  средства тормозящие свертывание крови средства...    NaN NaN NaN NaN
# 2                         натрия ойодгиппурат i  мбк    NaN NaN NaN NaN
# 3              тиреотропный гормон ирма  определений    NaN NaN NaN NaN
# 4               общий трийодтиронин риа  определений    NaN NaN NaN NaN
#
#   number                                          name_word type  \
# 0    NaN                                      [медикаменты]  NaN
# 1    NaN  [средства, тормозящие, свертывание, крови, сре...  NaN
# 2    NaN                     [натрия, ойодгиппурат, i, мбк]  NaN
# 3    NaN          [тиреотропный, гормон, ирма, определений]  NaN
# 4    NaN           [общий, трийодтиронин, риа, определений]  NaN
#
#                                             name_del  \
# 0                                      [медикаменты]
# 1  [тормозящие, свертывание, крови, антикоагуляци...
# 2                     [натрия, ойодгиппурат, i, мбк]
# 3          [тиреотропный, гормон, ирма, определений]
# 4           [общий, трийодтиронин, риа, определений]
#
#                                        name_del_text  len
# 0                                       медикаменты     1
# 1   средства тормозящие свертывание крови средств...    5
# 2                         натрия ойодгиппурат i мбк     4
# 3              тиреотропный гормон ирма определений     4
# 4               общий трийодтиронин риа определений     4

# %%
def transform_from_trade_to_orig(list_of_words):
    new_list = list()
    for word in list_of_words:
        if word in trade_to_official_dic.keys():
            new_list.append(trade_to_official_dic[word])
        else:
            new_list.append(word)
    return new_list

df['name_del'] = df['name_del'].apply(transform_from_trade_to_orig)

# %%
df.head()
# Out:
#          _id                                       product_name  quantity  \
# 0  1133680_0                                    Медикаменты\r\n       1.0
# 1   12192474  Средства тормозящие свертывание крови (средств...      10.0
# 2   12798155               Натрия о-йодгиппурат, 131-I (40 МБк)      42.0
# 3   12798156       Тиреотропный гормон ИРМА для 400 определений       7.0
# 4   12798157        Общий трийодтиронин РИА для 100 определений      12.0
#
#        price        sum country  \
# 0  488491.41  488491.41     NaN
# 1    5160.00   51600.00     NaN
# 2   16224.74  681439.08     NaN
# 3   15451.00  108157.00     NaN
# 4    3078.00   36936.00     NaN
#
#                                            name_norm  mg_ml  ml  mg   g  \
# 0                                    медикаменты\r\n    NaN NaN NaN NaN
# 1  средства тормозящие свертывание крови средства...    NaN NaN NaN NaN
# 2                         натрия ойодгиппурат i  мбк    NaN NaN NaN NaN
# 3              тиреотропный гормон ирма  определений    NaN NaN NaN NaN
# 4               общий трийодтиронин риа  определений    NaN NaN NaN NaN
#
#   number                                          name_word type  \
# 0    NaN                                      [медикаменты]  NaN
# 1    NaN  [средства, тормозящие, свертывание, крови, сре...  NaN
# 2    NaN                     [натрия, ойодгиппурат, i, мбк]  NaN
# 3    NaN          [тиреотропный, гормон, ирма, определений]  NaN
# 4    NaN           [общий, трийодтиронин, риа, определений]  NaN
#
#                                             name_del  \
# 0                                      [медикаменты]
# 1  [тормозящие, свертывание, крови, антикоагуляци...
# 2           [Аминосалициловая, ойодгиппурат, i, мбк]
# 3          [тиреотропный, гормон, ирма, определений]
# 4           [общий, трийодтиронин, риа, определений]
#
#                                        name_del_text  len
# 0                                       медикаменты     1
# 1   средства тормозящие свертывание крови средств...    5
# 2                         натрия ойодгиппурат i мбк     4
# 3              тиреотропный гормон ирма определений     4
# 4               общий трийодтиронин риа определений     4

# %% [markdown]
# # ------------------------------

# %%
import pickle

a = set_of_meds

with open('set_of_meds.pickle', 'wb') as handle:
    pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('set_of_meds.pickle', 'rb') as handle:
    b = pickle.load(handle)

print(a == b)
# Out:
# True

# %% [markdown]
# ## Частотный анализ и дополнительная чистка

# %%
del_list_2 = ["ин", "производные", "картонные", "картонные", "фл", "кислота",
              "пачки", "шт", "лечения", "приготовления", "группы", "флаконы", "ингаляционного", "контурные",
             "упаковки", "уп", "о", "в", "менее", "раствора", "рра","»","заменители", "пластиковые"
              "завод", "годности", "упаковке", "п", "х", "срок", "–", "мнн", "оао", "а",
             "инф", "форма", "комплекте", "дозировка", "страна", "препаратов", "лек", "темного", "производитель", 
             "ряда", "зао", "препарат", "стекла", "или", "мкгмл", "ряда", "жидкость", "от", "д", "пр", "лтд", "кол", "ооо", "их", 'применяемые', 'набор', 'определения', 'Вода', 'реагентов', 'крови' , 'тест', "применяемые", "системы", "медицине"
             "разные", "антибиотики", "сердечно", "сосудистые", "реагентов", "определения"]
del_list_2 += list(countries)

# %%
def my_func(a):
    return [x for x in a if x not in del_list_2]

# %%
df['name_del'] = df['name_del'].apply(lambda x : my_func(x))

# %%
from collections import Counter
words = list()
for i in tqdm(range(len(df))):
    words += df.loc[i, 'name_del']
count = Counter(words)
count.most_common(100)
# Out:
# 100%|██████████| 2096059/2096059 [00:39<00:00, 52432.94it/s]
# [('', 69837),
#  ('«', 54567),
#  ('Аминосалициловая', 48189),
#  ('инфузий', 41332),
#  ('к', 40993),
#  ('хлорид', 33238),
#  ('медицине', 29018),
#  ('см', 28247),
#  ('л', 25572),
#  ('диагностикумы', 24264),
#  ('антигены', 23786),
#  ('мм', 22300),
#  ('Камфора', 21696),
#  ('м', 20972),
#  ('разные', 19066),
#  ('доз', 17222),
#  ('лиофилизат', 17069),
#  ('выявления', 16526),
#  ('калия', 16018),
#  ('синтетические', 15386),
#  ('глюкоза', 15217),
#  ('питательные', 14774),
#  ('обмена', 14722),
#  ('стоматологические', 14600),
#  ('при', 14547),
#  ('вегетативную', 14499),
#  ('среды', 13828),
#  ('приг', 13741),
#  ('мемл', 13696),
#  ('мкг', 13624),
#  ('Диагностикум', 13540),
#  ('гр', 13486),
#  ('материал', 13376),
#  ('сыворотке', 13245),
#  ('средство', 13210),
#  ('диуретические', 12849),
#  ('ячейковые', 12657),
#  ('человека', 12479),
#  ('реагент', 12419),
#  ('процессы', 12337),
#  ('упаковка', 12273),
#  ('лиоф', 12127),
#  ('желчегонные', 12022),
#  ('наружного', 11926),
#  ('тестов', 11853),
#  ('Аллергены', 11617),
#  ('антитела', 11595),
#  ('сыворотка', 11473),
#  ('иммуноферментного', 11377),
#  ('подкожного', 10949),
#  ('ме', 10822),
#  ('сульфат', 10755),
#  ('магния', 10531),
#  ('кальция', 10413),
#  ('среда', 10413),
#  ('размер', 10266),
#  ('хирургические', 10235),
#  ('синапсы', 10192),
#  ('повязка', 10169),
#  ('методом', 10107),
#  ('антител', 10019),
#  ('тыс', 9934),
#  ('Дротаверин', 9779),
#  ('класса', 9531),
#  ('g', 9396),
#  ('ветеринарии', 9326),
#  ('комплект', 9313),
#  ('мышечные', 9290),
#  ('перевязочные', 9264),
#  ('тестсистема', 9255),
#  ('нервно', 9244),
#  ('состав', 9224),
#  ('сыворотки', 9041),
#  ('диски', 9032),
#  ('дезинфекционные', 8997),
#  ('новокаин', 8974),
#  ('назначения', 8886),
#  ('кровезаменители', 8863),
#  ('гель', 8683),
#  ('специальные', 8643),
#  ('р', 8601),
#  ('кат', 8318),
#  ('изделия', 8230),
#  ('шприц', 8199),
#  ('ед', 7896),
#  ('анализатора', 7896),
#  ('кислоты', 7890),
#  ('стерильная', 7751),
#  ('другие', 7559),
#  ('вода', 7505),
#  ('дезинфицирующее', 7505),
#  ('плазме', 7502),
#  ('медицинских', 7470),
#  ('нервные', 7459),
#  ('окончания', 7371),
#  ('тестполоски', 7321),
#  ('лидокаин', 7313),
#  ('кг', 7304),
#  ('суспензия', 7246),
#  ('прим', 7222)]

# %%
len([x for x in count.keys() if len(x) > 3])
# Out:
# 171301

# %%
sum(count.values()), len(count.keys())
# Out:
# (7431787, 179329)

# %% [markdown]
# ### old dict vs new dict from file

# %%
#old dict
df['len']=df['name_del'].apply(lambda x : len(x))
df_len1 = df[df['len'] == 1]
df_len1['name'] = df_len1['name_del'].map(lambda x: x[0])

old_med_dic=df_len1.loc[:,'name']
old_med_dic=pd.DataFrame(old_med_dic.drop_duplicates())
old_med_dic['class']=range(0,len(old_med_dic['name']))
old_med_dic['index']=old_med_dic['class']
old_med_dic=old_med_dic.set_index('index')

# %%
import editdistance
from tqdm import tqdm
# editdistance.eval()
unfound_matches = list()
for old_word in tqdm(list(old_med_dic['name'])):
    flag = False
    for new_word in set_of_meds:
        if editdistance.eval(old_word, new_word) <= 2:
            flag = True
            continue
    if not flag:
        unfound_matches.append(old_word)
# Out:
# 100%|██████████| 25357/25357 [18:37<00:00, 22.69it/s]

# %%
print(len(unfound_matches), unfound_matches)
# Out:
# 12663 ['медикаменты', 'разные', 'противовирусные', 'противораковые', 'стоматологические', 'местноанестезирующие', 'противогрибковые', 'кровезаменители', 'нитропрепараты', 'кортикоидного', 'дезинфекционные', 'ципрофлоксацинакос', 'цефоперазонвиал', 'доксициклинферейн', 'верованкомицин', 'органотерапевтические', 'цефепимджодас', 'скарификатор', 'паркинсонизма', 'анальгетики', 'амброксолвертемг', 'гормональные', 'пиразолона', 'рентгеноконтрастные', 'красители', 'химиотерапевтические', 'преднизолонникомед', 'диуретические', 'стимулирующие', 'антихолинэстеразные', 'спазмолитические', 'сульфаниламидные', 'веропипекуроний', 'феррумлек', 'метформинтева', 'меропенеммеропенемвиалпорошок', 'амикацинупак', 'азтреонамазтреаболфл', 'фосфомицинурофосфаболфл', 'ферментативного', 'винпоцетинтаблетки', 'летрозолтева', 'сырье', 'толперизонobl', 'глибенкламидметформин', 'бетаметазонгентамицинклотримазол', 'аммиакфлакон', 'валокординфлакон', 'янувиятаблетка', 'леркаментаблетка', 'димексидфлакон', 'леспефрилфлакон', 'реамберинфлакон', 'кодеинкофеинпарацетамолпропифеназон', 'амикацинферейн', 'меропенемвиал', 'цефазолинакос', 'гепаринферейн', 'сульфацилнатрия', 'цефепимвиал', 'амикацинвиал', 'азопирам', 'сайдезим', 'хлордез', 'энзимосепт', 'бикилц', 'сульфохлорантинд', 'дсифаантинаvмрекомб', 'дсифанвsag', 'дсифаhвeag', 'дсифаантинве', 'дсифаантиhbc', 'ифаантиhcvcm', 'ифаантиhcv', 'ифаантиhdv', 'дсвлкантиhcv', 'влкhbsag', 'дснbsagподтверждающий', 'дсифаантинеvм', 'дсифаантинеvg', 'дсифаантивкэм', 'дсифаантивкэg', 'вектопаротитigm', 'вектопаротитigg', 'ротавирусантигенифабест', 'уреаплазмозiggантитела', 'микоплазмозiggантитела', 'вектовпгiggстрип', 'вектовпгigмстрип', 'вектовэбvcaigмстрип', 'вектовэбеаiggстрип', 'вектовэбnaiggстрип', 'конвулекстаблетки', 'винпоцетинакос', 'котримоксазолбиосинтез', 'цефтазидимакос', 'дихлорэтиламина', 'инозинникотинамидрибофлавинянтарная', 'индапамидэналаприд', 'бриллиант', 'никаполицид', 'клиндезинспециаль', 'дезкорапид', 'никаамицид', 'стериллиум', 'техпластин', 'арифонретард', 'бронхомуналкапс', 'мильгаммакомпозитум', 'пенталгинicn', 'терафлекскапс', 'месналэнс', 'дакарбазинлэнс', 'этопозидтева', 'доксорубицинтева', 'верометотрексат', 'даунорубицинлэнс', 'цисплатинтева', 'фторурацилэбеве', 'метотрексатэбеве', 'митоксантронлэнс', 'винбластинлэнс', 'винкристинтева', 'токсокараiggифабест', 'ингалиптвиал', 'гепасолнео', 'аминосолнео', 'амлодипинпрана', 'хондроитинакос', 'ципротеронтева', 'аллопуринолэгис', 'нощбра', 'бисопрололпрана', 'верапамилферейн', 'метопрололакри', 'амиодаронтаблетки', 'гесперидиндиосмин', 'индапамидверте', 'дигидроэргокриптинкофеин', 'гидрохлоротиазидэналаприл', 'диклофенакакос', 'новопассит', 'пирацетамрихтер', 'мидокалмрихтер', 'оксампнатрий', 'вяжущие', 'витаиодурол', 'рибоксинвиал', 'эмоксиоптик', 'успокаивающие', 'пуриновые', 'феноксиметилпенициллиновые', 'адельфанэзидрекс', 'гидрокортизонрихтер', 'хаесстерил', 'новоглюккм', 'креатинин', 'тромбопластин', 'техаптвflтест', 'пиперациллинтазобактем', 'оптохин', 'нитроцефин', 'монтирующая', 'дилюент', 'холинэстераза', 'антитрепсин', 'рибосорб', 'ревертаl', 'тауринакос', 'тимололакос', 'вспомогательные', 'пломбировочные', 'ахдез', 'противогрибкового', 'цефалоспорины', 'барвипс', 'цитохромоксидазы', 'бордетелагар', 'кордаронсанофирр', 'амиодаронорганикатаб', 'лизинотонактавистаб', 'диуверпливатаб', 'фозикардактавистаб', 'амприланkрkaтаб', 'метоклопрамидсотексрр', 'листенонникомед', 'димедролдальхимфармрр', 'тавегилникомед', 'тавегилфамар', 'метопрололратиофармратиофарм', 'димедролвиал', 'винпоцетинсар', 'альфанормикс', 'амоксициллинклавулановая', 'феррофольгамма', 'нутризон', 'метронидазолакос', 'противоопухолевые', 'бромгексинакри', 'ципрофлоксацинфпо', 'слепочные', 'гаммаглобулины', 'противомалярийные', 'фотосенсибилизирующие', 'хлорсодержащие', 'веровинкристин', 'доксорубицинлэнс', 'лейковоринлэнс', 'карбоплатинлэнс', 'солумедрол', 'фторурациллэнс', 'диклофенакдиклогенраствор', 'кетопрофенфламакс', 'мелоксикамартрозан', 'метопрололратиофарм', 'не ...

# %% [markdown]
# ### meds from file

# %%
intersection_meds = set()
not_intersection_meds = set()
for c in count.keys():
    if c in set_of_meds:
        intersection_meds.add(c)
    else:
        not_intersection_meds.add(c)

# %%
len(intersection_meds)
# Out:
# 6617

# %%
len(not_intersection_meds)
# Out:
# 172712

# %%
not_intersection_meds
# Out:
# {'',
#  'фенофталеина',
#  'виантигеном',
#  'пальмитата',
#  'нагрузочных',
#  'плесневелые',
#  'лgiulini',
#  'санпропускники',
#  'одностадийныйобразец',
#  'стопорному',
#  'регентконцентрированный',
#  'соответствовует',
#  'флхдисков',
#  'биксов',
#  'microв',
#  'комплектпрокладок',
#  'альфаадреноблокатор',
#  'цмвlgм',
#  'гарьяна',
#  'презерватива',
#  'желатинасо',
#  'mcladosporium',
#  'ипидакриннейромидинраствор',
#  'тимманна',
#  'борозды',
#  'дальтонстепень',
#  'трописетронтропиндол',
#  'третиноинкапсулы',
#  'mdaoxldlокислительно',
#  'balkanpharmatroyan',
#  'tosoh',
#  'ритромицин',
#  'растворителемампула',
#  'флкапкльница',
#  'saphire',
#  'onetouch®',
#  'биоотходов',
#  'федеральных',
#  'шлифпорошка',
#  'etik',
#  'белкагл',
#  'кепамики',
#  'великобританиявтор',
#  'che',
#  'соски',
#  'сердечнососудистыми',
#  'фиссилгерметик',
#  'konicaminolta',
#  'доксирубицинлэнс',
#  'модернизации',
#  'бхим',
#  'барабаны',
#  'дсифаафпкат',
#  'эозинат',
#  'стрептозотоцин',
#  'фармстандрт',
#  'торговли',
#  'мгмгфлмл',
#  'сту',
#  'неонатальное',
#  'терефталевый',
#  'микроальбулина',
#  'гермитического',
#  'валерианатаб',
#  'dlisocitric',
#  'метиловым',
#  'blastocyst',
#  'kfl',
#  'гидрохлоридпиридоксингидрохлорид',
#  'поверхностноактивными',
#  'дихлоридом',
#  'спиртовхлоргексидинчасамин',
#  'метопроло',
#  'углеродом',
#  'полирпаст–zf',
#  'мальтоза—dмоногидрат',
#  'рраргинилальфааспартиллизилвалилтирозиларгининшткальция',
#  'ифасабест',
#  'кабине',
#  'umbilical',
#  'трахеотомический',
#  'довелпины',
#  'пролангированного',
#  'перегидроль',
#  'азиррус',
#  'цефоперазонасульбактама',
#  'спичсоломка',
#  'износостойкой',
#  'аспарагиназааспарагиназа',
#  'полиэтилентерафталат',
#  'зрт',
#  'испанияferrer',
#  'дифенгидраминдимедроламп',
#  'тавакомб',
#  'контрацепции',
#  'бонд',
#  'инъеций',
#  'серебристого',
#  'тараканами',
#  'кроличьим',
#  'кортексинмгмл',
#  'дугообразной',
#  'млсистема',
#  'пролежни',
#  'заболеванийантибиотики',
#  'опп',
#  'xxl',
#  'анузолроссия',
#  'ребра',
#  'разбавленного',
#  'масламп',
#  'россияупнетhypochlorite',
#  'бисопрол',
#  'withclips',
#  'бумажки',
#  'китайпроизводитель',
#  'хоспира',
#  'календулой',
#  'цнфоперазон',
#  'алпвх',
#  'цисплатинлэнсконцентрат',
#  '–diagnostic',
#  'туберкулинаили',
#  'республики',
#  'выскокий',
#  'цветостабильностью',
#  'раком',
#  'каракут',
#  'ячейная',
#  'gfv',
#  'гидрохлоридльвовдиалек',
#  'резорбируемого',
#  'велеикобритания',
#  'айвэкс',
#  'аудиометр',
#  'фексофакт',
#  'форте®',
#  'шлицевая',
#  'pdc',
#  'гериатрического',
#  'rbкр',
#  'гидролизата',
#  'этилметилгидроксилиридина',
#  'прочиепротамина',
#  'капсид',
#  'лэбс',
#  'minicap',
#  'фолликулинстимулирующего',
#  'кислотта',
#  'диэт',
#  'нимодипиннимотоп',
#  'подворотом',
#  'паровоздушному',
#  'екклетки',
#  'вектонвcag',
#  'itn',
#  'россиятаб',
#  'млst',
#  'ларингельн',
#  'suitable',
#  'antigencde',
#  'агарчапмана',
#  'витаплант',
#  'биполярной',
#  'нейтропении',
#  'accuсhek',
#  'кгооо',
#  'антивгсфактор',
#  'cиликоновая',
#  'ррez',
#  'альвеофактбэг',
#  'финспирид',
#  'бензилпеницил',
#  'сертифицирован',
#  'иммунохромотографическая',
#  'дестроза',
#  'бикарбонатом',
#  'fсмазкаспрей',
#  'установить',
#  'вискозаполиэстер',
#  'морфолиноэ',
#  'калийфосфатный',
#  'за\xadжимом',
#  'кровезаменителигидроксиэтилкрахмал',
#  'ацетилфуран',
#  'цветостабильны',
#  'тергитол',
#  'twister',
#  'триглицерид',
#  'экспресспанель',
#  'растворналичие',
#  'менингококкасреда',
#  'чрескожных',
#  'беталокзол',
#  'фармацевтикароссия',
#  'специфическим',
#  'мембранному',
#  'эдтаsarsted',
#  'креатинкиназаmb',
#  'лифо',
#  'биодобавок',
#  'wpss',
#  'изопреновой',
#  'сульфацич',
#  'лакмусовая',
#  'тироидифааттпоооо',
#  'листу',
#  'esthetik',
#  'xxхмл',
#  'млнедтысед',
#  'гормонролственный',
#  'композитпломбировочный',
#  'компактного',
#  'грль',
#  'тестсиcтема',
#  'бесплатной',
#  'стеклораствор',
#  'валиками',
#  'медсанчасть',
#  'упаковкапенопластовый',
#  'диафанопределение',
#  'шнурах',
#  'рактопамина',
#  'васафорс',
#  'социального',
#  'eшт',
#  'хлорпирамин',
#  'белокмл',
#  'светоотвер',
#  'чашеобразные',
#  'mtaangetus',
#  'фронтальныет',
#  'swabsampler',
#  '–временный',
#  'каналовс',
#  'колюще',
#  'ктааугментин',
#  'устойчивая',
#  'giaизгиб',
#  'coulterr',
#  'лбанка',
#  'мigм',
#  'опн',
#  'перинатального',
#  'изокерит',
#  'antirat',
#  'таксат',
#  'clostri',
#  'фальк',
#  'романовскомупрофессионал',
#  'синтомицинамеропенем',
#  'гемеопатические',
#  'intecc',
#  'кочаннойcabbage',
#  'квамалел',
#  'ксенгетикс',
#  'пботулиническ',
#  'lgмифабест',
#  'флмлаппликаторышт',
#  'медикамент',
#  'карбамазепинакриамитриптилинторендо',
#  'алтиазем',
#  'хирургнстер',
#  'вазелиновоег',
#  'histolytica',
#  'метопрололobl',
#  'осадочная',
#  'fbgen',
#  'онкоифасаобщий',
#  'диаклиннкдифф',
#  'аскорбинка',
#  'тэг',
#  'мочег',
#  'тентрал',
#  'нсм',
#  'покрплен',
#  'zma',
#  'сульфатхондроитина',
#  'аспергиллlgg',
#  'antielastin',
#  'гидрохлоридвитамин',
#  'латентной',
#  'свеклы',
#  'team',
#  'ггаксессуары',
#  'офлаксацином',
#  'латекснтест',
#  'кобальтохромовых',
#  'омезсофаримексиндустрия',
#  'sa',
#  'межзубный',
#  'альважель',
#  'iggigaдсtr',
#  'контейнеы',
#  'уринерс',
#  'сопровождаться',
#  'двухкамерная',
#  'mediclean',
#  'кетерол',
#  'светоотвержда',
#  'определекние',
#  'пыльце',
#  'точкамонореактив',
#  'ифанвs',
#  'опухолями',
#  'прохождение',
#  'амоксицилли',
#  'атовент',
#  'кишеч',
#  'antecubital',
#  'ыгол',
#  'отинума',
#  'человекааrc',
#  'аспект',
#  'облегченного',
#  'пкожн',
#  'groupa',
#  'радио',
#  'полирезистентных',
#  'украинадигоксин',
#  'капроанат',
#  'корнеплод',
#  'включено',
#  'колонизацию',
#  'перокситерил',
#  'гидросиликаттальк',
#  'маннитомагрм',
#  'полимерныеозон',
#  'сетегис®',
#  'дифенгидраминраствор',
#  'merckmillipore',
#  'ноотропный',
#  'мочевым',
#  'testddimercheck',
#  'терм',
#  'динитрад',
#  'отливка',
#  'юнитестбм',
#  'бионаймбионайм',
#  'иммунофиксация',
#  'фамодипин',
#  'мюллеркауфмана',
#  'ревматических',
#  'наборштумфлаковpicofit',
#  'пооб',
#  'скипар',
#  'берлинхемименарини',
#  'гидроксиэтиленкрахмал',
#  'полн',
#  'эндоскопии',
#  'ооороссиякапсулы',
#  'оборотов',
#  'phap',
#  'алтсептм',
#  'изменяется',
#  'тремонормтаблетки',
#  'эстенд',
#  'креатенина',
#  'ж',
#  'глуматин',
#  'нещелочной',
#  'произведено',
#  'corchol',
#  'сердикс',
#  'esthetic',
#  'фармацантибиотики',
#  'амоксициклинклавуланат',
#  'эндокринную',
#  'интервет',
#  'brca',
#  'капозидроссия',
#  'реагентовлиофилизированные',
#  'вконтроль',
#  'генфасталт',
#  'корнье',
#  'бараклюд®',
#  'компотентыгемицеллюлоза',
#  'аlт',
#  'препаратвитамин',
#  'наборранорасширитель',
#  'нормодипинтаблетки',
#  'реканализации',
#  'мен',
#  'экстракторе',
#  'покрывающего',
#  'hbvhdvfl',
#  'эндохирургическая',
#  'маннитолманнит',
#  'регидратации',
#  'gk',
#  'однокомпонетный',
#  'судьфадимезин',
#  'синтон',
#  'глазами',
#  'продольными',
#  'брикеты',
#  'промывкисша',
#  'месокал',
#  'тампонада',
#  'хф',
#  'тиретропный',
#  'sпрокладки',
#  'ррп',
#  'дляобработкисредство',
#  'ввенгрия',
#  'placental',
#  'mgнабор',
#  'кооперэйшн',
#  'бумажныедля',
#  'хуксол',
#  'бала',
#  'коррозийкрасительотдушка',
#  'нц',
#  'холтер',
#  'перфузионных',
#  'шовным',
#  'линц',
#  'дибазолубф',
#  'клиникофармакологическая',
#  '–врамед',
#  'соответствующее',
#  'µl',
#  'состава',
#  'hhvigg',
#  'валетек',
#  'elisa',
#  'суспезией',
#  'lex',
#  'шовенфранция',
#  'парацетамолкодеинкофеин',
#  'cмсм',
#  'пополнителяfixerandreplenisher',
#  'флксероформ',
#  'иммунотритивный',
#  'beiyuan',
#  'лизинотонтаблетки',
#  'lopl',
#  'спирамициневро',
#  'внутрьфл',
#  'энзимпав',
#  'bтаурин',
#  'пластизоля',
#  'роg',
#  'осадочных',
#  'эндосольве',
#  'микроэлектродрн',
#  'минотрансферазы',
#  'ммproendo',
#  'стоматологич',
#  'солодка',
#  'piptaz',
#  'дсифаантицвмg',
#  'trachomatisх',
#  'защитный',
#  'альфамикроглобулин',
#  'верошпирактон',
#  'сохранённой',
#  'гркалия',
#  'glul',
#  'маниилглибенк',
#  'апикальным',
#  'растут',
#  'gegou',
#  'камня',
#  'сифотриц',
#  'прочиекалий',
#  'dermagrip',
#  'эпидбиомеддиагностикаооог',
#  'diapes',
#  'кардиом',
#  'тетраацетилендиамина',
#  'cквизи',
#  'гмбхфарма',
#  'дистилированая',
#  'мидриацилфлакон',
#  'стафиллококка',
#  'тримеллитовому',
#  'колебаниях',
#  'химерного',
#  'упмгмл',
#  'литниковый',
#  'окончательного',
#  'скобками',
#  'обычная',
#  'дезинфекционныеникасупер',
#  'аспарагинатраствор',
#  'аопольша',
#  'флуктиказонфликоназе',
#  'каучуковой',
#  'прочиеэтанолраствор',
#  'токами',
#  'араб',
#  'кислотаникотинамидпантотеновая',
#  'атестованный',
#  'благотворительная',
#  'картонныелин',
#  'флшпрдозамл',
#  'цитрул',
#  'министар',
#  'шайнмикс',
#  'сиквенсовый',
#  'мае',
#  'токсо–igm',
#  'твёрдосплавная',
#  'регидратирующее',
#  'норфолоксацин',
#  'javel',
#  'возникает',
#  'гепаринова',
#  'тпктест',
#  'культивировании',
#  'pedo',
#  'енолаза',
#  'мовизр',
#  'каплесчитатель',
#  'млкоррег',
#  'дистализации',
#  'герметична',
#  'мннибупрофен',
#  'заметным',
#  'канистралитр',
#  'программатора',
#  'аvantor',
#  'ггkerr',
#  'антивирусным',
#  'околоверхушечных',
#  'идентифицируемые',
#  'полигексаметиленбигуанидин',
#  'кислоталевомицетинфурагинципрофлоксацинкотримаксазолглюренормманинилкорвалолдигоксинэналаприлуголь',
#  'missory',
#  'эквиваленнт',
#  'спиртосмываеыые',
#  'атgвпг',
#  'элеовит',
#  'сверхупругая',
#  'бромгексинрр',
#  'бетадинрр',
#  'lfcглазурь',
#  'растворсбрфл',
#  'мепитак',
#  'факичная',
#  'кетггут',
#  'fluidstable',
#  'non',
#  'gonnorhoeae',
#  'серебр',
#  'карбоксиметилкразмал',
#  'кровяные',
#  'экстирп',
#  'антихамлме',
#  'lмм',
#  'волоколамское',
#  'рентгенхирургическом',
#  'сиккотим',
#  'иммунохемилюминисцентным',
#  'акетоглутарат',
#  'мюллерахилтона',
#  'синдбис',
#  'комбинезон',
#  'ницфгруппл',
#  'jga',
#  'бупренорф',
#  'беклометазонбеклазон',
#  'миролюттаблетки',
#  'камеры',
#  'mag',
#  'трамадрол',
#  'fkстандарт',
#  'кровезаменителейкитай',
#  'panel',
#  'меронемшт',
#  'трехкомпонентный',
#  'бусинами',
#  'антипаллидумсумарные',
#  'npwt',
#  'концции',
#  'желчный',
#  'кипн',
#  'системаобщий',
#  'пластификатор',
#  'малатдегидрогеназаедллактатдегидрогеназа',
#  'гутгалакс',
#  'эмоксиоптика',
#  'биэластик',
#  'блок',
#  'оценка',
#  'накостного',
#  'всенаде',
#  'гентамицинвысокая',
#  'мнтк',
#  'эноксопарин',
#  'флуксетин',
#  'белосерые',
#  'флаконпульверизатор',
#  'стеризолмыло',
#  'агатgenscreen',
#  'полифосфатов',
#  'гидрохлоротиазидэналаприлэнапн',
#  'lлизинацетат',
#  'прочиесупрастин',
#  'уменьшенный',
#  'мтсfl',
#  'непроницаемы',
#  'интенсивный',
#  'турдыева',
#  'дяя',
#  'сепарационных',
#  'млegisвенгерская',
#  'спенсермеропенемципрофлоксоцинцефазолинампициллинбензилпенициллинцефтриаксонгентамицинэнтерофурил',
#  'stacompact',
#  'расклеивания',
#  'мкгн',
#  'шигелласальмонелла',
#  'цемионколорстеклоиономерный',
#  'паст',
#  'пантогаммл',
#  'smile',
#  'co',
#  'мисталь',
#  'eternus',
#  'фламакса',
#  'ихатадфактор',
#  'культвирования',
#  'лифилизированный',
#  'млспрей',
#  'агшияжуанг',
#  'млшприцы',
#  'офтальмолога',
#  'соприкосновения',
#  'фруктов',
#  'регистрационном',
#  'цефоксим',
#  'тропанина',
#  'пентоксифиллинэском',
#  'новопасситтолперизонobl',
#  'дсрпгаантилюискат',
#  'отношениямно',
#  'закупорки',
#  'подсоединяемую',
#  'аланинглутамином',
#  'гликозидкоргликардамп',
#  'перформаштупак',
#  'трахомати',
#  'иммунофааллерген',
#  'дрейнобэг',
#  'генерал',
#  'fabric',
#  'спреи',
#  'министерильный',
#  'относительной',
#  'omnifiх',
#  'тазобактаммкгмкг',
#  'единый',
#  'эстрадиолst',
#  'резалютпро',
#  'бромгексингвайфенезинсальбутамоласкорил',
#  'факторами',
#  'ny',
#  'луночками',
#  'гемоглобинновов',
#  'коррекцииреконструкции',
#  'смазочные',
#  'рw',
#  'open',
#  'нимпомин',
#  'бетадином',
#  'анализаторароссия',
#  'гранулезоклеточной',
#  'атштест',
#  'сукцинатреамберин',
#  'оас',
#  'ддимеров',
#  'малаясупер',
#  'hbz',
#  'фибринмономерного',
#  'урографинмг',
#  'даксастабл',
#  'дистиллир',
#  'антиh',
#  'calcium',
#  'standards',
#  'aseptoprint',
#  'полидентшприц',
#  'тромбоплатин',
#  'нутризин',
#  'ифаантиhbсмскрин',
#  'мвформетингемодезкальция',
#  'гестоз',
#  'натpия',
#  'вэбеaigg',
#  'fabфрагмент',
#  'выев',
#  'цефкситин',
#  'госнии',
#  'равный',
#  'yersiniaenterocolitica',
#  'диаманд',
#  'циркулирующих',
#  'млducera',
#  'крестовый',
#  'каптоприлтаблетки',
#  'баларпанн',
#  'эксирпации',
#  'четыреххлористом',
#  'sterivac',
#  'млпорошок',
#  'триосидент',
#  'isoenzyme',
#  'жидким',
#  'ректификованного',
#  'lkpep',
#  'данном',
#  'плато',
#  'цист',
#  'финляндияшерингплау',
#  'натриянитроксолин',
#  'cwwb',
#  'железоново',
#  'млрек',
#  'тестовантитромбин',
#  'стерлизационные',
#  'тиоктоцид',
#  'диагель',
#  'ааааоаора',
#  'коринотоксагар',
#  'субстратный',
#  'плавления',
#  'репаглинидторговое',
#  'цитратном',
#  'профилин',
#  'электролитовпакет',
#  'альфанафтола',
#  'гвмв',
#  'тестисистемы',
#  'ivfblastocyst',
#  'maintance',
#  'сишуа',
#  'несмыв',
#  'емь',
#  'пластм',
#  'рсутки',
#  'заболеванийотменавыбрать',
#  'бипролтаблетки',
#  'vgs',
#  'отмыва',
#  'цинкфосфетный',
#  'оксистурбухалер',
#  'ph',
#  'наматрасникомразмер',
#  'колено',
#  'пшеницы',
#  'дессауторнау',
#  'cialloy',
#  'светонепрозрачной',
#  'миллиметровый',
#  'сульфаткофеин',
#  'мидокалммг',
#  'bagp',
#  'периода',
#  'сумах',
#  'бытрорасворимый',
#  'кумбс',
#  'энлаприла',
#  'инжектора',
#  'баночке',
#  'acr',
#  'diasis',
#  'векторроссия',
#  'глобофарм',
#  'аппависк',
#  'Сорбитол',
#  'метронидазолоао',
#  'снrandoxвеликобритания',
#  'эргокальциферолальфа',
#  'байонетный',
#  'филтекz',
#  'нестерилизованная',
#  'россияпроизводство',
#  'внутриматочное',
#  'ксирканг',
#  'таквинин',
#  'вили',
#  'сшивающими',
#  'карборундовым',
#  'fepс',
#  'глицерофосфата',
#  'силикона',
#  'мкмолькгсуткимоча',
#  'афлутоп',
#  'насадка–распылитель',
#  'lightкерамко',
#  'вектовпгiggавидностьтестсистема',
#  'кеii',
#  'спитровой',
#  'диагностикукмы',
#  'стрептоккоковый',
#  'сокращает',
#  'сoreантигену',
#  'engraulisencrassicholusponticus',
#  'барана',
#  'мгфенирамин',
#  'аналаприл',
#  'шейной',
#  'бара',
#  'benckiserвеликобритания',
#  'nlколпачки',
#  'аццтаб',
#  'nконец',
#  'плазмь',
#  'рмгмл',
#  'ecf',
#  'соединенные',
#  'microtubes',
#  'местрептокиназа',
#  'камбала',
#  'silcofixpovi',
#  'флаконбромгексин',
#  'uriselect',
#  'владмиваф',
#  'обработку',
#  'аротоанализ',
#  'фуросемидд',
#  'требоваться',
#  'послеоперационая',
#  'маммографа',
#  'сорбц',
#  'септолен',
#  'фансидартабл',
#  'реконван',
#  'маскареспиратор',
#  'rhdrhw',
#  'фронтальная',
#  'flohrостроконечный',
#  'токопроводящим',
#  'турецкая',
#  'пустыми',
#  'роцефинхоффманн',
#  'сек',
#  'трансдер',
#  'бутон',
#  'helveticusг',
#  'бонадермл',
#  'истощение',
#  'вгсблотбест',
#  '–kb',
#  'дексафорт',
#  'etdle',
#  'игс',
#  'углеводный',
#  'lсм',
#  'люмбальным',
#  'метроклопрамид',
#  'ацидофильн',
#  'внутрьмсгг',
#  'разовые',
#  'ферметивным',
#  'фосфолюгель',
#  'omniplastна',
#  'ципринолраствор',
#  'хлорацетон',
#  'creme',
#  'джибонд',
#  'турбухалерпор',
#  'ддаймерddimer',
#  'пролонгдейст',
#  'аоисландияпр',
#  'гемапаксин',
#  'окрытые',
#  'прочиенеингаляционное',
#  'субълингвальные',
#  'дозшприцы',
#  'хладагентом',
#  'плотностьскрытая',
#  'цефорабол',
#  'бримонидина',
#  'диметакрилатные',
#  'макрофагальный',
#  'ммхммхлист',
#  'ветович',
#  'удмл',
#  'антикоррозийных',
#  'лтдтаблетки',
#  'микросомальной',
#  'протеиннасыщенных',
#  'острыхожоги',
#  'глицеродегидрогеназы',
#  'руквязки',
#  'снсоо',
#  'сосудом',
#  'требующая',
#  'сульфатов',
#  'гидрохлортиазидгидрохлортиазид',
#  'мельдонийкардионат',
#  'рмикроэлектрод',
#  'пекарных',
#  'прочиепроявитель',
#  'фенестрированная',
#  'флуфеназинмодитен',
#  'прикрепления',
#  'хлоридформа',
#  'пакетикигр',
#  'винпоцетинфезамаспаркамкордиаминэуфиллин',
#  'компонентыгмицеллюлоза',
#  'закупаемых',
#  'фибринолитическиеамлодипин',
#  'взрослыхsmall',
#  'флуорексон',
#  'кольцово',
#  'референсныйхх',
#  'интородьюсер',
#  'рисунком',
#  'rr',
#  'enterobacteriace',
#  'артериявена',
#  'желчегонныегипотиазид',
#  'лейкопластырьфармлайнвеликобритания',
#  'хламодоспор',
#  'кожн',
#  'грань',
#  'irn',
#  'тестауп',
#  'positions',
#  'тетрагидробензохинолинол',
#  'инкубирование',
#  'lisebio',
#  'украинарр',
#  'лишенных',
#  'картонныен',
#  'reporter',
#  'кгаа',
#  'ампрр',
#  'фунгигизон',
#  'краем',
#  'мелисептолфоам',
#  'жс',
#  'никапироксан',
#  'cacctaaacttgggagaacatggt',
#  'pnu',
#  'эритромицинлиофилизат',
#  'настила',
#  'пилотимол®',
#  'поливинихлоридным',
#  'bsten',
#  'лиофилизатат',
#  'мкуз',
#  'эклампсия',
#  'верепамил',
#  'прорисована',
#  'транспортирующих',
#  'маалокстаб',
#  'диахимцитостейнгкгематоксилин',
#  'электрофарез',
#  'груп',
#  'ветрянки',
#  'литейной',
#  'стен',
#  'пузырн',
#  'prз',
#  'ммнестерильная',
#  'аспирационноирригационная',
#  'комок',
#  'парацетамолтрамадол',
#  'udуниверсальный',
#  'низко',
#  'нминсулин',
#  'калибровочную',
#  'капель',
#  'разделительная',
#  'экспрессдиагностические',
#  'дозирдейств',
#  'бережно',
#  'hewbridge',
#  'ингибиторы',
#  'стеризолфлакон',
#  'std',
#  'стеклоиономер',
#  'ёный',
#  'расходный',
#  'леводопы',
#  'кальцияфраксипаринраствор',
#  'проявляющего',
#  'стз',
#  'антираб',
#  'генноинж',
#  'дуогель',
#  'гемоститическая',
#  'lтироксинми',
#  'рамиприлхартил',
#  'полиолефиновые',
#  'восьмиграник',
#  'транексамроссия',
#  'бензилпеициллин',
#  'конкортаб',
#  'hmинсулин',
#  'лейковоринлэнслиоф',
#  'разъедающее',
#  'винилполисилоксановая',
#  'этилендиаминтетрауксксную',
#  'слабительныеливолюк',
#  'обработаны',
#  ...}

# %%
for c in not_intersection_meds:
    if c not in unfound_matches:
        del count[c]

# %%
count.most_common(50)
# Out:
# [('инфузий', 41332),
#  ('к', 40993),
#  ('хлорид', 33238),
#  ('медицине', 29018),
#  ('л', 25572),
#  ('диагностикумы', 24264),
#  ('антигены', 23786),
#  ('м', 20972),
#  ('разные', 19066),
#  ('лиофилизат', 17069),
#  ('выявления', 16526),
#  ('калия', 16018),
#  ('глюкоза', 15217),
#  ('стоматологические', 14600),
#  ('при', 14547),
#  ('вегетативную', 14499),
#  ('среды', 13828),
#  ('гр', 13486),
#  ('материал', 13376),
#  ('диуретические', 12849),
#  ('ячейковые', 12657),
#  ('человека', 12479),
#  ('реагент', 12419),
#  ('процессы', 12337),
#  ('наружного', 11926),
#  ('антитела', 11595),
#  ('сыворотка', 11473),
#  ('иммуноферментного', 11377),
#  ('подкожного', 10949),
#  ('сульфат', 10755),
#  ('магния', 10531),
#  ('кальция', 10413),
#  ('среда', 10413),
#  ('хирургические', 10235),
#  ('повязка', 10169),
#  ('антител', 10019),
#  ('тыс', 9934),
#  ('g', 9396),
#  ('перевязочные', 9264),
#  ('тестсистема', 9255),
#  ('сыворотки', 9041),
#  ('дезинфекционные', 8997),
#  ('новокаин', 8974),
#  ('кровезаменители', 8863),
#  ('гель', 8683),
#  ('р', 8601),
#  ('изделия', 8230),
#  ('кислоты', 7890),
#  ('стерильная', 7751),
#  ('вода', 7505)]

# %%
df['name_del_text']=df['name_del'].apply(lambda x: ' ' + ' '.join(x) + ' ')
df['len']=df['name_del'].apply(lambda x: len(x))

# %%
len(df)
# Out:
# 2096059

# %% [markdown]
# ## Новая кластеризация

# %%
med_dic = dict()
klass = 0
for c in count.keys():
    med_dic[c] = klass
    klass += 1

# %% [markdown]
# ### критическая дистанция левенштейна - 1

# %%
# %%time
import editdistance
from collections import defaultdict
# from tqdm import tqdm
med_dic_list = list(med_dic.keys())
typo_dict = defaultdict(str)

for i in tqdm(range(len(med_dic_list) - 1)):
    if typo_dict[med_dic_list[i]] == '':
        typo_dict[med_dic_list[i]] = med_dic_list[i]
    for j in range(i + 1, len(med_dic_list)):
        if (editdistance.eval(med_dic_list[i], med_dic_list[j]) == 1):
            try:
#                 print(med_dic_list[j], med_dic_list[i])
                typo_dict[med_dic_list[j]] =med_dic_list[i]
                del med_dic[med_dic_list[j]]
            except KeyError:
                pass
# Out:
#  43%|████▎     | 8320/19279 [09:17<08:42, 20.99it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# KeyboardInterrupt:

# %%
len(med_dic)
# Out:
# 16679

# %% [markdown]
# ### стопслова

# %%
stopwords = [('п', 71944),
 ('ц', 22922),
 ('дства', 8625),
 ('едства', 8619),
 ('действ', 5499),
 ('лек', 3713),
 ('систем', 3711),
 ('цен', 3222),
 ('гр', 2463),
 ('инг', 2007),
 ('упаковки', 1637),
 ('лекарств', 1421),
 ('фарм', 1374),
 ('ингаляционного', 894),
 ('лп', 852),
 ('прам', 843),
 ('препаратов', 658),
 ('комплекте', 646),
 ('наименован', 331),
 ('действующих', 326),
 ('включая', 276),
 ('шприц', 264),
 ('противосуд', 174),
 ('наркотических', 97),
 ('нейролептические', 87),
 ('вода', 81),
 ('on', 75),
 ('анестезии', 58),
 ('медикаменты', 57),
 ('прочих', 42),
 ('вегетативную', 39),
 ('брал', 39),
 ('риской', 39),
 ('системы', 38),
 ('действующе', 34),
 ('лекарства', 33),
 ('седотивные', 30),
 ('нейролептики', 30),
 ('сильнодействующие', 26),
 ('анальгетики', 25)]

# %%
for s in stopwords:
    if s[0] in med_dic:
        del med_dic[s[0]]

# %%
len(med_dic)
# Out:
# 16666

# %%
del_keys = list()
for key in med_dic.keys():
    if len(key) < 4:
        del_keys.append(key)
for key in del_keys:
    del med_dic[key]

# %%
len(med_dic)
# Out:
# 16597

# %% [markdown]
# ## Matrix of distances

# %%
dist = np.zeros((len(med_dic), len(med_dic)))
med_dic_list = list(med_dic)

# %%
# %%time
import editdistance

for i in tqdm(range(len(med_dic_list) - 1)):
    dist[i][i] = 0
    for j in range(i + 1, len(med_dic_list)):
        dist[i][j] = editdistance.eval(med_dic_list[i], med_dic_list[j])
        dist[j][i] = dist[i][j]
# Out:
# 100%|██████████| 2922/2922 [00:16<00:00, 173.21it/s]
# Wall time: 16.9 s

# %% [markdown]
# ### very efficient : 11s vs 5m13s

# %%
np.save('lev_distances.np', dist)

# %% [markdown]
# ## Groupization

# %%
df['name_del'].apply(lambda x : len(x)).describe()
# Out:
# count    2.096059e+06
# mean     3.075181e+00
# std      5.703595e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      3.420000e+02
# Name: name_del, dtype: float64

# %%
#### name_del fixing typos:
def fixed(word):
    if word in typo_dict.keys():
        return typo_dict[word]
    return word

def fix_typo(l):
    new_list = list()
    for word in l[:2]:
        new_list.append(fixed(word))
    return new_list

# %%
df['name_del'] = df['name_del'].apply(lambda x: [s for s in x if len(s) > 3])

# %%
# %%time
df['name_del'] = df['name_del'].apply(lambda x: fix_typo(x))

# %%
df.to_csv('new_medical_2012_full.csv', encoding='utf8')

# %%
df = pd.read_csv('new_medical_2012_full.csv', encoding='utf8')

# %%
df['len']=df['name_del'].apply(lambda x: len(x))
df = df[df['len'] > 0]
len(df)

# %%
import ast
def get_klass(s):
#     s = ast.literal_eval(s)
#     for k in med_dic.keys():
#         if k in s:
#             return med_dic[k]
    x = list(set(med_dic.keys()).intersection(set(s)))
    if len(x) > 0:
        return x[0]
    return None

# %%
from collections import defaultdict

# %%
inverse_dict = defaultdict(str)
for k in med_dic.keys():
    inverse_dict[med_dic[k]] = k
def get_med_from_klass(s):
    if s==None:
        return 'Not found'
    return inverse_dict[s]

# %%
import ast
def get_klass(s):
    s = ast.literal_eval(s)
    for k in med_dic.keys():
        if k in s:
            return med_dic[k]
    return None

# %%
tqdm.pandas()
df['klass'] = df['name_del'].progress_apply(lambda x : get_klass(x))

# %%
len(df[df['klass'] == None])

# %%
df['number'].isna().sum(), df['type'].isna().sum(), df['country'].isna().sum()

# %%
None==None

# %% [markdown]
# ## Сделаем группизацию по активному веществу и номеру

# %% [markdown]
# ## Где номер - NaN, найдем ближайший "кластер" по средней цене этого кластера

# %%
df['price'].isna().sum()
# Out:
# 4536

# %%
df = df[~df['price'].isna()]
df['price'].isna().sum()
# Out:
# 0

# %%
len(df)
# Out:
# 2091523

# %%
# def find_nearest(array, value):
#     array = np.asarray(array)
#     idx = (np.abs(array - value)).argmin()
#     return idx
# def eliminate_nan_from_number(df):
#     df = df.copy()
#     grouped = df.groupby(['klass', 'number', 'type'])
# #     key[0] - klass, key[1] - number
#     for key, value in tqdm(zip(grouped.groups.keys(), grouped.groups.values()), total=len(grouped.groups)):
#         #         known klass and both number and type are unknown
#         if (not isinstance(key[2], str) and not isinstance(key[1], str)):
#             if len(grouped.groups[key]) == 1:#c[key[0]] == 1:
#                 df.loc[value, 'type'] = 'unknown'
#                 df.loc[value, 'number'] ='unknown'
#             if len(grouped.groups[key]) == 2:
#                 for key_ in grouped.groups.keys():
#                     if (isinstance(key_[2], str) or isinstance(key_[1], str)) and key_[0] == key[0]:
#                         df.loc[value, 'number'] = key_[1]
#                         df.loc[value, 'type'] = key_[2]
#             else:
#                 medians_by_key = dict()
#                 for key_, value_ in zip(grouped.groups.keys(), grouped.groups.values()):
#                     if (key_[0] == key[0]) and (isinstance(key_[2], str) or isinstance(key_[1], str)):
#                         medians_by_key[(key_[1], key_[2])] = np.median(np.array(df.loc[value_, 'price']))
#                 for idx in value:
#                     cur_price = df.loc[idx, 'price']
#                     nearest = -1
#                     nearest_dif = 1e9
#                     for key_pair in medians_by_key.keys():
# #                         print(medians_by_key[key_pair] ,cur_price)
#                         if abs(medians_by_key[key_pair] - cur_price) < nearest_dif:
#                             nearest_dif = abs(medians_by_key[key_pair] - cur_price)
#                             nearest = key_pair
#                     try:
#                         df.loc[idx, 'number'] = nearest[0]
#                     except:
#                         print(nearest, cur_price, medians_by_key.values())
#                     df.loc[idx, 'type'] = nearest[1]
# #         known klass and known type but unknown number
#         if (not isinstance(key[1], str) and isinstance(key[2], str)):
#             if len(grouped.groups[key]) == 1:#c[key[0]] == 1:
#                 df.loc[value, 'number'] = 'unknown'
#             if len(grouped.groups[key]) == 2:
#                 for key_ in grouped.groups.keys():
#                     if isinstance(key_[1], str) and (key_[0] == key[0] and key_[2] == key[2]):
#                         df.loc[value, 'number'] = key_[1]
#             else:
#                 medians_by_key = dict()
#                 for key_, value_ in zip(grouped.groups.keys(), grouped.groups.values()):
#                     if (key_[0] == key[0] and key_[2] == key[2]) and isinstance(key_[1], str):
#                         medians_by_key[key_[1]] = np.median(np.array(df.loc[value_, 'price']))
#                 for idx in value:
#                     cur_price = df.loc[idx, 'price']
#                     nearest = -1
#                     nearest_dif = 1e9
#                     for key_ in medians_by_key.keys():
#                         if abs(medians_by_key[key_] - cur_price) < nearest_dif:
#                             nearest_dif = abs(medians_by_key[key_] - cur_price)
#                             nearest = key_
#                     df.loc[idx, 'number'] = nearest
# #         known klass and known number but unknown type
#         if (not isinstance(key[2], str) and isinstance(key[1], str)):
#             if len(grouped.groups[key]) == 1:#c[key[0]] == 1:
#                 df.loc[value, 'type'] = 'unknown'
#             if len(grouped.groups[key]) == 2:
#                 for key_ in grouped.groups.keys():
#                     if isinstance(key_[2], str) and (key_[0] == key[0] and key_[1] == key[1]):
#                         df.loc[value, 'type'] = key_[2]
#             else:
#                 medians_by_key = dict()
#                 for key_, value_ in zip(grouped.groups.keys(), grouped.groups.values()):
#                     if (key_[0] == key[0] and key_[1] == key[1]) and isinstance(key_[2], str):
#                         medians_by_key[key_[2]] = np.median(np.array(df.loc[value_, 'price']))
#                 for idx in value:
#                     cur_price = df.loc[idx, 'price']
#                     nearest = -1
#                     nearest_dif = 1e9
#                     for key_ in medians_by_key.keys():
#                         if abs(medians_by_key[key_] - cur_price) < nearest_dif:
#                             nearest_dif = abs(medians_by_key[key_] - cur_price)
#                             nearest = key_
#                     df.loc[idx, 'type'] = nearest
#     return df
        
# df_new = eliminate_nan_from_number(df)

# %%
'a' 1 liquid - ...
'b' 2 tablet - ...
'c' None liquid - 5 шт, 200 руб
'd' 2 None - 10 шт, 500 руб
'e' 2 tablet - 450 руб

# %%
grouped = df.groupby(['klass', 'number', 'type'])

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
def eliminate_nan_from_number(df):
    df = df.copy()
    grouped = df.groupby(['klass', 'number', 'type'])
#     key[0] - klass, key[1] - number
    for key, value in tqdm(zip(grouped.groups.keys(), grouped.groups.values()), total=len(grouped.groups)):
        #         known klass and both number and type are unknown
        if (not isinstance(key[2], str) and not isinstance(key[1], str)):
            medians_by_key = dict()
            for key_, value_ in zip(grouped.groups.keys(), grouped.groups.values()):
                if (key_[0] == key[0]) and (isinstance(key_[2], str) or isinstance(key_[1], str)):
                    medians_by_key[(key_[1], key_[2])] = np.median(np.array(df.loc[value_, 'price']))
            if len(medians_by_key) == 0:
                df.loc[value, 'number'] = None
                df.loc[value, 'type'] = None
                continue
            for idx in value:
                cur_price = df.loc[idx, 'price']
                nearest = -1
                nearest_dif = 1e9
                for key_pair in medians_by_key.keys():
#                         print(medians_by_key[key_pair] ,cur_price)
                    if abs(medians_by_key[key_pair] - cur_price) < nearest_dif:
                        nearest_dif = abs(medians_by_key[key_pair] - cur_price)
                        nearest = key_pair
                df.loc[value, 'number'] = nearest[0]
                df.loc[value, 'type'] = nearest[1]
                
    for key, value in tqdm(zip(grouped.groups.keys(), grouped.groups.values()), total=len(grouped.groups)):
#         known klass and known type but unknown number
        if (not isinstance(key[1], str) and isinstance(key[2], str)):
            medians_by_key = dict()
            for key_, value_ in zip(grouped.groups.keys(), grouped.groups.values()):
                if (key_[0] == key[0] and key_[2] == key[2]) and isinstance(key_[1], str):
                    medians_by_key[key_[1]] = np.median(np.array(df.loc[value_, 'price']))
            if len(medians_by_key) == 0:
                df.loc[value, 'number'] = None
                df.loc[value, 'type'] = None
                continue
            for idx in value:
                cur_price = df.loc[idx, 'price']
                nearest = -1
                nearest_dif = 1e9
                for key_ in medians_by_key.keys():
                    if abs(medians_by_key[key_] - cur_price) < nearest_dif:
                        nearest_dif = abs(medians_by_key[key_] - cur_price)
                        nearest = key_
                df.loc[idx, 'number'] = nearest
#         known klass and known number but unknown type
        if (not isinstance(key[2], str) and isinstance(key[1], str)):
            medians_by_key = dict()
            for key_, value_ in zip(grouped.groups.keys(), grouped.groups.values()):
                if (key_[0] == key[0] and key_[1] == key[1]) and isinstance(key_[2], str):
                    medians_by_key[key_[2]] = np.median(np.array(df.loc[value_, 'price']))
            if len(medians_by_key) == 0:
                df.loc[value, 'number'] = None
                df.loc[value, 'type'] = None
                continue
            for idx in value:
                cur_price = df.loc[idx, 'price']
                nearest = -1
                nearest_dif = 1e9
                for key_ in medians_by_key.keys():
                    if abs(medians_by_key[key_] - cur_price) < nearest_dif:
                        nearest_dif = abs(medians_by_key[key_] - cur_price)
                        nearest = key_
                df.loc[idx, 'type'] = nearest
    return df
        
df_new = eliminate_nan_from_number(df)

# %%
df_new.to_csv('new_medical_2012_with_number_filled_full.csv', encoding='utf8')

# %%
df_new['number'].isna().sum(), df_new['type'].isna().sum(), df_new['country'].isna().sum()

# %%
df_new.head(50)
# Out:
#     Unnamed: 0       _id                                       product_name  \
# 0            0  12798676  Гидрокортизон-Рихтер сусп для в/м и внутрисуст...
# 1            1  12798677                Лопирел таб. п/об пленочн. 75мг №28
# 2            2  12798708                         Плавикс таб. п/о 300мг №10
# 3            3  12798709  Фраксипарин р-р для п/к введ. 9,5тыс. анти-Ха ...
# 4            4  12798710  Тромбофлюкс лиоф. пригот. р-ра в/в и в/а введ....
# 5            5  12799474                        Амоксициллин таб. 250мг №20
# 6            6  12799359                         Азитромицин капс. 250мг №6
# 7            7  12799473  Амикацин-Виал пор. пригот. р-ра в/в и в/м введ...
# 8            8  12799475                        Амоксициллин таб. 500мг №20
# 9            9  12799476  Ампициллин пор. пригот. р-ра в/в и в/м введ. 1...
# 10          10  12799477  Бензилпенициллина натр. соль пор. д/приг. р-ра...
# 11          11  12799478                              Левосин мазь 40г туба
# 12          12  12799479         Левомеколь мазь для наружного прим. 40г №1
# 13          13  12799480                    Видокцин 100мг лиоф д/ин в/в №1
# 14          14  12799481                     Клотримазол ваг. таб. 100мг №6
# 15          15  12799555                         Метронидазол таб. 0,25 №20
# 16          16  12799556                     Нитроксолин таб. п/о 0,05г №50
# 17          17  12799557                      Офлоксацин таб. п/о 400мг №10
# 18          18  12799558       Микофлюкан р-р д/инф. 200мг/100мл фл. п/э №1
# 19          19  12799559                           Флуконазол капс.150мг №1
# 20          20  12799560       Ципрофлоксацин р-р для инф. 2мг/мл фл. 100мл
# 21          21  12799590                  Ципрофлоксацин таб. п/о 500мг №10
# 22          22  12799591                  Ципрофлоксацин таб. п/о 250мг №10
# 23          23  12800075   Ремедиа  таблетки покрытые  оболочкой 500мг №10
# 24          24  12800076   Ремедиа  таблетки покрытые  оболочкой 750мг №10
# 25          25  12800171     Элефлокс р-р д/инф. 500мг фл. полиэт. 100мл №1
# 26          26  12800172                          Ломацин таб. п/о 400мг №5
# 27          27  12800173              Авелокс р-р д/инф. 1,6мг/мл фл. 250мл
# 28          28  12800174                          Авелокс таб. п/о 400мг №5
# 29          29  12800175                       Норбактин таб. п/о 400мг №10
# 30          30  12800303                Заноцин р-р д/инф. 2мг/мл фл. 100мл
# 31          31  12800304                         Абактал таб. п/о 400мг №10
# 32          32  12800305  Абактал концентрат для приготовления раствора ...
# 33          33  12802221        Амоксиклав Квиктаб таб. дисперг. 1000мг №14
# 34          34  12802222  Амоксиклав пор. пригот. сусп. д/вн. приема  12...
# 35          35  12802229  Амоксиклав таб. покрытые пленочной оболочкой 2...
# 36          36  12802230  Амоксиклав пор. д/приг р-ра для в/в введ 1г + ...
# 37          37  12802254  мписид пор. д/приг. р-ра для в/м введ. фл.1,5г...
# 38          38  12802255  Метронидазол раствор для внутривенного введени...
# 39          39  12802256                   Сульфасалазин таб. п/о 500мг №50
# 40          40  12802261  Цефпар СВ порошок для приготовления раствора д...
# 41          41  13193145                                          Сульпирид
# 42          42  12864323   Динисорб конц. пригот. р-ра д/инф. амп. 10мл №10
# 43          43  12864324  Изокет аэр. подъязычный дозир. 1,25мг/доза 300...
# 44          44  12864979  Кардикет табл. пролонгированного действия 40 м...
# 45          45  12864980                              Пектрол таб. 40мг №30
# 46          46  12864981  Нитроспрей спрей подъязычный дозированный 1% (...
# 47          47  12864982  Нитро (нитроглицерин) конц. д/инф. амп. 5мг/мл...
# 48          48  12871109  препараты для лечения дистресс-синдрома у недо...
# 49          49  12946015                                 Актовегин 2,0 №25.
#
#     quantity     price        sum country  \
# 0       40.0     84.53    3381.20     NaN
# 1       90.0    689.57   62061.30     NaN
# 2        6.0   2308.63   13851.78     NaN
# 3       10.0   1484.56   14845.60     NaN
# 4       20.0   8472.64  169452.80     NaN
# 5      150.0     23.99    3598.50     NaN
# 6      480.0    102.64   49267.20     NaN
# 7     2000.0     32.28   64560.00     NaN
# 8      150.0     44.29    6643.50     NaN
# 9      700.0      9.11    6377.00     NaN
# 10     600.0      4.59    2754.00     NaN
# 11     360.0     64.27   23137.20     NaN
# 12     360.0     56.45   20322.00     NaN
# 13      20.0     74.31    1486.20     NaN
# 14     120.0     15.82    1898.40     NaN
# 15     300.0      6.83    2049.00     NaN
# 16      30.0     34.35    1030.50     NaN
# 17      35.0     41.33    1446.55     NaN
# 18      18.0    280.75    5053.50     NaN
# 19      60.0     19.40    1164.00     NaN
# 20      70.0     22.47    1572.90     NaN
# 21     260.0     19.66    5111.60     NaN
# 22      50.0     10.70     535.00     NaN
# 23      15.0    944.51   14167.65     NaN
# 24      10.0   1144.25   11442.50     NaN
# 25      20.0    351.65    7033.00     NaN
# 26      50.0    149.25    7462.50     NaN
# 27      10.0   2505.93   25059.30     NaN
# 28      40.0   1033.07   41322.80     NaN
# 29      30.0     68.08    2042.40     NaN
# 30      20.0     70.80    1416.00     NaN
# 31       4.0    135.00     540.00     NaN
# 32      70.0    457.15   32000.50     NaN
# 33      60.0    389.46   23367.60     NaN
# 34      36.0    104.99    3779.64     NaN
# 35       6.0    206.58    1239.48     NaN
# 36      50.0   1000.46   50023.00     NaN
# 37    1200.0    171.00  205200.00     NaN
# 38    6000.0     19.76  118560.00     NaN
# 39       2.0    216.44     432.88     NaN
# 40     200.0    179.61   35922.00     NaN
# 41      40.0    103.80    4152.00     NaN
# 42      48.0    807.30   38750.40     NaN
# 43      18.0    378.37    6810.66     NaN
# 44       6.0    195.77    1174.62     NaN
# 45      60.0    114.62    6877.20     NaN
# 46      30.0     75.72    2271.60     NaN
# 47      12.0    197.86    2374.32     NaN
# 48      10.0  21000.00  210000.00     NaN
# 49      22.0    900.17   19803.74     NaN
#
#                                             name_norm  mg_ml     ml      mg  \
# 0   гидрокортизонрихтер сусп вм внутрисуст вв мгмл...   25.0    5.0     NaN
# 1                       лопирел таб  поб пленочн  мг     NaN    NaN    75.0
# 2                                 плавикс таб  по мг     NaN    NaN   300.0
# 3   фраксипарин рр пк введ  тыс  антиха мемл шприц...    NaN    0.3     NaN
# 4   тромбофлюкс лиоф  пригот  рра вв ва введ  млн ...    NaN    1.5     NaN
# 5                               амоксициллин таб  мг     NaN    NaN   250.0
# 6                               азитромицин капс  мг     NaN    NaN   250.0
# 7   амикацинвиал пор  пригот  рра вв вм введ  фл  мг     NaN    NaN   500.0
# 8                               амоксициллин таб  мг     NaN    NaN   500.0
# 9     ампициллин пор  пригот  рра вв вм введ  мг фл      NaN    NaN  1000.0
# 10  бензилпенициллина натр  соль пор  приг  рра вм...    NaN    1.0     NaN
# 11                                левосин мазь г туба    NaN    NaN     NaN
# 12                 левомеколь мазь наружного прим  г     NaN    NaN     NaN
# 13                            видокцин мг лиоф ин вв     NaN    NaN   100.0
# 14                          клотримазол ваг  таб  мг     NaN    NaN   100.0
# 15                                метронидазол таб       NaN    NaN     NaN
# 16                             нитроксолин таб  по г     NaN    NaN     NaN
# 17                             офлоксацин таб  по мг     NaN    NaN   400.0
# 18                    микофлюкан рр инф  мгмл фл  пэ     NaN  100.0     NaN
# 19                                флуконазол капс мг     NaN    NaN   150.0
# 20                 ципрофлоксацин рр инф  мгмл фл  мл    2.0  100.0     NaN
# 21                         ципрофлоксацин таб  по мг     NaN    NaN   500.0
# 22                         ципрофлоксацин таб  по мг     NaN    NaN   250.0
# 23         ремедиа  таблетки покрытые  оболочкой мг      NaN    NaN   500.0
# 24         ремедиа  таблетки покрытые  оболочкой мг      NaN    NaN   750.0
# 25                элефлокс рр инф  мг фл  полиэт  мл     NaN  100.0   500.0
# 26                                ломацин таб  по мг     NaN    NaN   400.0
# 27                        авелокс рр инф  мгмл фл  мл    1.6  250.0     NaN
# 28                                авелокс таб  по мг     NaN    NaN   400.0
# 29                              норбактин таб  по мг     NaN    NaN   400.0
# 30                        заноцин рр инф  мгмл фл  мл    2.0  100.0     NaN
# 31                                абактал таб  по мг     NaN    NaN   400.0
# 32  абактал концентрат приготовления раствора внут...   80.0    5.0     NaN
# 33               амоксиклав квиктаб таб  дисперг  мг     NaN    NaN  1000.0
# 34  амоксиклав пор  пригот  сусп  вн  приема  мг м...    NaN  100.0     NaN
# 35  амоксиклав таб  покрытые пленочной оболочкой  ...    NaN    NaN   125.0
# 36         амоксиклав пор  приг рра вв введ г  мг фл     NaN    NaN   200.0
# 37  мписид пор  приг  рра вм введ  фл г компл  рас...    NaN    NaN     NaN
# 38  метронидазол раствор внутривенного введения  м...    5.0  100.0     NaN
# 39                          сульфасалазин таб  по мг     NaN    NaN   500.0
# 40  цефпар св порошок приготовления раствора внутр...    NaN    NaN     NaN
# 41                                          сульпирид    NaN    NaN     NaN
# 42           динисорб конц  пригот  рра инф  амп  мл     NaN   10.0     NaN
# 43      изокет аэр  подъязычный дозир  мгдоза доз мл     NaN   15.0     NaN
# 44     кардикет табл  пролонгированного действия  мг     NaN    NaN    40.0
# 45                                   пектрол таб  мг     NaN    NaN    40.0
# 46  нитроспрей спрей подъязычный дозированный   мг...    NaN   10.0     NaN
# 47       нитро нитроглицерин конц  инф  амп  мгмл мл     5.0    2.0     NaN
# 48  препараты лечения дистресссиндрома недоношенны...    NaN    NaN     NaN
# 49                                        актовегин      NaN    NaN     NaN
#
#         g number                                          name_word     type  \
# 0     NaN     №1  ['гидрокортизонрихтер', 'сусп', 'вм', 'внутрис...   liquid
# 1     NaN    №28         ['лопирел', 'таб', 'поб', 'пленочн', 'мг']   tablet
# 2     NaN    №10                     ['плавикс', 'таб', 'по', 'мг']   tablet
# 3     NaN    №10  ['фраксипарин', 'рр', 'пк', 'введ', 'тыс', 'ан...   liquid
# 4     NaN     №1  ['тромбофлюкс', 'лиоф', 'пригот', 'рра', 'вв',...   liquid
# 5     NaN    №20                      ['амоксициллин', 'таб', 'мг']   tablet
# 6     NaN     №6                      ['азитромицин', 'капс', 'мг']   tablet
# 7     NaN     №1  ['амикацинвиал', 'пор', 'пригот', 'рра', 'вв',...   powder
# 8     NaN    №20                      ['амоксициллин', 'таб', 'мг']   tablet
# 9     NaN     №1  ['ампициллин', 'пор', 'пригот', 'рра', 'вв', '...   powder
# 10    NaN     №1  ['бензилпенициллина', 'натр', 'соль', 'пор', '...   powder
# 11  40.00   None                   ['левосин', 'мазь', 'г', 'туба']     None
# 12  40.00     №1   ['левомеколь', 'мазь', 'наружного', 'прим', 'г']    cream
# 13    NaN   None             ['видокцин', 'мг', 'лиоф', 'ин', 'вв']     None
# 14    NaN     №6                ['клотримазол', 'ваг', 'таб', 'мг']   tablet
# 15    NaN    №20                            ['метронидазол', 'таб']   tablet
# 16   0.05    №50                  ['нитроксолин', 'таб', 'по', 'г']   tablet
# 17    NaN    №10                  ['офлоксацин', 'таб', 'по', 'мг']   tablet
# 18    NaN     №1    ['микофлюкан', 'рр', 'инф', 'мгмл', 'фл', 'пэ']   liquid
# 19    NaN     №1                       ['флуконазол', 'капс', 'мг']   tablet
# 20    NaN     №1  ['ципрофлоксацин', 'рр', 'инф', 'мгмл', 'фл', ...   liquid
# 21    NaN    №10              ['ципрофлоксацин', 'таб', 'по', 'мг']   tablet
# 22    NaN    №10              ['ципрофлоксацин', 'таб', 'по', 'мг']   tablet
# 23    NaN    №10  ['ремедиа', 'таблетки', 'покрытые', 'оболочкой...   tablet
# 24    NaN    №10  ['ремедиа', 'таблетки', 'покрытые', 'оболочкой...   tablet
# 25    NaN     №1  ['элефлокс', 'рр', 'инф', 'мг', 'фл', 'полиэт'...   liquid
# 26    NaN     №5                     ['ломацин', 'таб', 'по', 'мг']   tablet
# 27    NaN   None       ['авелокс', 'рр', 'инф', 'мгмл', 'фл', 'мл']     None
# 28    NaN     №5                     ['авелокс', 'таб', 'по', 'мг']   tablet
# 29    NaN    №10                   ['норбактин', 'таб', 'по', 'мг']   tablet
# 30    NaN   None       ['заноцин', 'рр', 'инф', 'мгмл', 'фл', 'мл']     None
# 31    NaN    №10                     ['абактал', 'таб', 'по', 'мг']   tablet
# 32    NaN    №10  ['абактал', 'концентрат', 'приготовления', 'ра...   liquid
# 33    NaN    №14  ['амоксиклав', 'квиктаб', 'таб', 'дисперг', 'мг']   tablet
# 34  25.00   None  ['амоксиклав', 'пор', 'пригот', 'сусп', 'вн', ...     None
# 35    NaN    №15  ['амоксиклав', 'таб', 'покрытые', 'пленочной',...   tablet
# 36   1.00     №5  ['амоксиклав', 'пор', 'приг', 'рра', 'вв', 'вв...   powder
# 37   1.50    №30  ['мписид', 'пор', 'приг', 'рра', 'вм', 'введ',...   powder
# 38    NaN     №1  ['метронидазол', 'раствор', 'внутривенного', '...   liquid
# 39    NaN    №50               ['сульфасалазин', 'таб', 'по', 'мг']   tablet
# 40   1.00   None  ['цефпар', 'св', 'порошок', 'приготовления', '...     None
# 41    NaN    №10                                      ['сульпирид']  capsule
# 42    NaN    №10  ['динисорб', 'конц', 'пригот', 'рра', 'инф', '...   liquid
# 43    NaN     №1  ['изокет', 'аэр', 'подъязычный', 'дозир', 'мгд...    spray
# 44    NaN    №50  ['кардикет', 'табл', 'пролонгированного', 'дей...   tablet
# 45    NaN    №30                           ['пектрол', 'таб', 'мг']   tablet
# 46    NaN     №1  ['нитроспрей', 'спрей', 'подъязычный', 'дозиро...    spray
# 47    NaN     №5  ['нитро', 'нитроглицерин', 'конц', 'инф', 'амп...   liquid
# 48    NaN    NaN  ['препараты', 'лечения', 'дистресссиндрома', '...   liquid
# 49    NaN    №25                                      ['актовегин']   liquid
#
#                                              name_del  \
# 0               ['гидрокортизонрихтер', 'внутрисуст']
# 1                              ['лопирел', 'пленочн']
# 2                                         ['плавикс']
# 3   ['фраксипарин', 'антиха', 'мемл', 'шприц', 'од...
# 4                   ['тромбофлюкс', 'лиоф', 'пригот']
# 5                                    ['амоксициллин']
# 6                                     ['азитромицин']
# 7                          ['амикацинвиал', 'пригот']
# 8                                    ['амоксициллин']
# 9                            ['ампициллин', 'пригот']
# 10      ['бензилпенициллина', 'натр', 'соль', 'прим']
# 11                                ['левосин', 'туба']
# 12                ['левомеколь', 'наружного', 'прим']
# 13                               ['видокцин', 'лиоф']
# 14                                    ['клотримазол']
# 15                                   ['метронидазол']
# 16                                    ['нитроксолин']
# 17                                     ['офлоксацин']
# 18                                     ['микофлюкан']
# 19                                     ['флуконазол']
# 20                                 ['ципрофлоксацин']
# 21                                 ['ципрофлоксацин']
# 22                                 ['ципрофлоксацин']
# 23                                        ['ремедиа']
# 24                                        ['ремедиа']
# 25                             ['элефлокс', 'полиэт']
# 26                                        ['ломацин']
# 27                                        ['авелокс']
# 28                                        ['авелокс']
# 29                                      ['норбактин']
# 30                                        ['заноцин']
# 31                                        ['абактал']
# 32                                ['абактал', 'Вода']
# 33               ['амоксиклав', 'квиктаб', 'дисперг']
# 34                           ['амоксиклав', 'пригот']
# 35                                     ['амоксиклав']
# 36                             ['амоксиклав', 'прим']
# 37          ['амписид', 'прим', 'компл', 'лидокаина']
# 38                                   ['метронидазол']
# 39                                  ['сульфасалазин']
# 40                                 ['цефпар', 'Вода']
# 41                                      ['сульпирид']
# 42                             ['динисорб', 'пригот']
# 43       ['изокет', 'подъязычный', 'дозир', 'мгдоза']
# 44                                       ['кардикет']
# 45                                        ['пектрол']
# 46  ['нитроспрей', 'подъязычный', 'дозированный', ...
# 47                         ['нитро', 'нитроглицерин']
# 48  ['дистресссиндрома', 'недоношенных', 'ибупрофе...
# 49                                      ['актовегин']
#
#                                         name_del_text  len  klass
# 0                     гидрокортизонрихтер внутрисуст    37     -1
# 1                                    лопирел пленочн    22      0
# 2                                            плавикс    11      1
# 3    фраксипарин пк тыс антиха мемл шприц однодозо...   67      2
# 4                  тромбофлюкс лиоф пригот ва млн ме    33      5
# 5                                       амоксициллин    16      8
# 6                                        азитромицин    15      9
# 7                                амикацинвиал пригот    26     10
# 8                                       амоксициллин    16      8
# 9                                  ампициллин пригот    24     11
# 10           бензилпенициллина натр соль приг млн ед    45     12
# 11                                      левосин туба    19     14
# 12                         левомеколь наружного прим    35     15
# 13                                     видокцин лиоф    20     18
# 14                                   клотримазол ваг    15     19
# 15                                      метронидазол    16     20
# 16                                       нитроксолин    15     21
# 17                                        офлоксацин    14     22
# 18                                     микофлюкан пэ    14     23
# 19                                        флуконазол    14     24
# 20                                    ципрофлоксацин    18     25
# 21                                    ципрофлоксацин    18     25
# 22                                    ципрофлоксацин    18     25
# 23                                           ремедиа    11     26
# 24                                           ремедиа    11     26
# 25                                   элефлокс полиэт    22     27
# 26                                           ломацин    11     28
# 27                                           авелокс    11     29
# 28                                           авелокс    11     29
# 29                                         норбактин    13     30
# 30                                           заноцин    11     31
# 31                                           абактал    11     32
# 32                                      абактал Вода    19     32
# 33                        амоксиклав квиктаб дисперг    36     33
# 34                              амоксиклав пригот вн    24     33
# 35                                        амоксиклав    14     33
# 36                                   амоксиклав приг    22     17
# 37                   мписид приг компл лидокаина гхл    41     17
# 38                                      метронидазол    16     20
# 39                                     сульфасалазин    17     36
# 40                                    цефпар св Вода    18     37
# 41                                         сульпирид    13     39
# 42                                   динисорб пригот    22     40
# 43               изокет подъязычный дозир мгдоза доз    44     41
# 44                                          кардикет    12     42
# 45                                           пектрол    11     43
# 46   нитроспрей подъязычный дозированный мгдоза до...   84     44
# 47                               нитро нитроглицерин    26     45
# 48   дистресссиндрома недоношенных Ибупрофен курос...   61     47
# 49                                         актовегин    13     48

# %%
df_new = pd.read_csv('new_medical_2012_with_number_filled.csv', encoding='utf8')

# %%
print(df_new['sum'].sum())
print(df_new[df_new['number'].isna() | df_new['klass'] == -1].sum())

# %%
print(df_new['sum'].sum())
print(df_new[df_new['number'].isna()].sum())

# %% [markdown]
# # possibly

# %%
https://www.rlsnet.ru/books_book_id_3_page_4.htm
аэроз. - аэрозоль
аэроз.доз. - аэрозоль дозированный
аэроз.доз.мите - аэрозоль дозированный с минимальной дозировкой/действием
аэроз.доз.форте - аэрозоль дозированный с максимальной дозировкой/действием
аэроз.ингал. - аэрозоль ингаляционный
аэроз.ингал.доз. - аэрозоль ингаляционный дозированный
аэроз.наз. - аэрозоль назальный
аэроз.наз.доз. - аэрозоль назальный дозированный
аэроз.наружн. - аэрозоль для наружного применения
аэроз.орал. - аэрозоль для перорального применения
аэроз.орал.доз. - аэрозоль для перорального применения дозированный
бальзам наружн. - бальзам для наружного применения
бальзам орал. - бальзам для перорального применения
бинт/салф.стерил. - бинт с салфеткой стерильные
брикеты парафин. - брикеты парафиновые
брикеты пиротехн. - брикеты пиротехнические
вспомог. в-ва - вспомогательные вещества
гель ваг. - гель вагинальный
гель глазн. - гель глазной
гель д/волос - гель для волос
гель зубн. - гель зубной
гель наз. - гель для носа
гель наружн. - гель для наружного применения
гель орал. - гель для перорального применения
гель рект. - гель ректальный
гель стер. - гель стерильный
гель стомат. - гель стоматологический
гель форте - гель с максимальной дозировкой/действием
гель-ТДТС - гель – трансдермальная терапевтическая система
генератор инсектиц.дыма - генератор инсектицидного дыма
гран. - гранулы
гран.в/п - гранулы для приготовления раствора для внутриполостного введения
гран.д/капель - гранулы для приготовления капель
гран.д/р-ра орал. - гранулы для приготовления раствора для перорального применения
гран.д/рассас. - гранулы для рассасывания
гран.д/сиропа - гранулы для приготовления сиропа
гран.д/сусп. - гранулы для приготовления суспензии
гран.д/сусп.д/ин. - гранулы для приготовления суспензии для инъекций
гран.д/сусп.орал. - гранулы для приготовления суспензии для перорального применения
гран.д/сусп.орал.детск. - гранулы для приготовления суспензии для перорального применения для детей
гран.детск. - гранулы для детей
гран.доз. - гранулы дозированные
гран.доз.д/р-ра орал. - гранулы дозированные для приготовления раствора для перорального применения
гран.доз.д/р-ра орал.детск. - гранулы дозированные для приготовления раствора для перорального применения для детей
гран.доз.форте - гранулы дозированные с максимальной дозировкой/действием
губка стер. - губка стерильная
губка стер.пресс. - губка стерильная прессованная
драже жев. - драже жевательное
драже пролонг. - драже пролонгированного действия
драже форте - драже с максимальной дозировкой/действием
жидк. - жидкость
жидк./комплект - жидкость в комплекте
жидк.д/ин. - жидкость для инъекций
жидк.д/ингал.наркоза - жидкость для ингаляционного наркоза
жидк.д/снятия лака - жидкость для снятия лака
жидк.наружн. - жидкость для наружного применения
жидк.орал. - жидкость для перорального применения
имплант. - имплантаты
ингал.карман. - ингалятор карманный
каплеты детск. - каплеты для детей
каплеты п.о. - каплеты, покрытые оболочкой
капли глазн. - капли глазные
капли глазн./наз. - капли глазные и для носа
капли глазн./ушн. - капли глазные и ушные
капли д/ингал. - капли для ингаляций
капли детск. - капли детские
капли зубн. - капли зубные
капли наз. - капли для носа
капли наз.детск. - капли для носа детские
капли наружн. - капли для наружного применения
капли орал. - капли для перорального применения
капли орал. и д/ингал. - капли для перорального применения и для ингаляций
капли орал./наружн. - капли для перорального и наружного применения
капли орал.детск. - капли для перорального применения детские
капли ушн. - капли ушные
капс. - капсулы
капс./чай лек. - капсулы с чаем лекарственным
капс.д/имплант. - капсулы для имплантаций
капс.д/имплант.депо - капсулы для имплантаций пролонгированного действия
капс.д/ин.депо - капсулы для инъекций пролонгированного действия
капс.депо - капсулы депо
капс.детск. - капсулы для детей
капс.мягк. - капсулы мягкие
капс.мягк.форте - капсулы мягкие форте
капс.наружн. - капсулы для наружного применения
капс.пролонг. - капсулы пролонгированного действия
капс.раствор./кишечн. - капсулы, растворимые в кишечнике
капс.рект. - капсулы ректальные
капс.рект.детск. - капсулы ректальные для детей
капс.ретард - капсулы ретард
капс.ретард.форте - капсулы ретард с максимальной дозировкой/действием
капс.тверд. - капсулы твердые
капс.форте - капсулы с максимальной дозировкой/действием
карандаш мед. - карандаш медицинский
клей фибрин. - клей фибриновый
композ. - композиция
контрац.в/мат. - контрацептив внутриматочный
конусы зубн. - конусы зубные
конц. - концентрат
конц.д/дез.р-ра - концентрат для приготовления дезинфекционного раствора
конц.д/ин. - концентрат для приготовления инъекций
конц.д/инф. - концентрат для приготовления инфузий
конц.д/инф. и д/р-ра орал. - концентрат для приготовления инфузий и раствора для перорального применения
конц.д/р-ра наружн. - концентрат для приготовления раствора для наружного применения
конц.д/р-ра орал. - концентрат для приготовления раствора для перорального применения
конц.жидк. - концентрат жидкий
конц.наружн. - концентрат для наружного применения
конц.наружн./орал. - концентрат для наружного и перорального применения
конц.орал. - концентрат для перорального применения
корневища и корни/брикеты - корневища и корни в брикетах
корневища с корнями/брикеты - корневища с корнями в брикетах
корневища/брикеты - корневища в брикетах
корни/брикеты - корни в брикетах
крем ваг. - крем вагинальный
крем д/лица - крем по уходу за кожей лица
крем д/рук - крем по уходу за кожей рук
крем детск. - крем для детей
крем наз. - крем для носа
крем-субст. - крем–субстанция для приготовления косметических средств
кубики орал. - кубики для перорального применения
лак д/ногтей - лак для ногтей
лак инсект. - лак инсектицидный
лек.раст.сырье - лекарственное растительное сырье
лента бум. - лента бумажная
линим. - линимент
листья/брикеты - листья в брикетах
лосьон детск. - лосьон детский
мазь ваг. - мазь вагинальная
мазь глазн. - мазь глазная
мазь жирн. - мазь жирная
мазь интраназ. - мазь для носа
мазь п/жирн. - мазь полужирная
мазь рект. - мазь ректальная
мазь-ТДТС - мазь – трансдермальная терапевтическая система
маска д/лица - маска по уходу за кожей лица
масло детск. - масло детское
масло наружн. - масло для наружного применения
маты инсектиц. - маты инсектицидные
мк/гран. - микрогранулы
мк/гран.доз. - микрогранулы дозированные
мк/драже - микродраже
мк/капс. - микрокапсулы
мк/капс.д/ин. - микрокапсулы для приготовления раствора для инъекций
мк/сферы лиоф.д/ин. - микросферы лиофилизированные для инъекций
молочко д/лица - молочко по уходу за кожей лица
мыло жидк. - мыло жидкое
набор диагн. - набор диагностический
набор диагн.многокомп. - набор диагностический многокомпонентный
настойка матр. - настойки матричные
нити зубн. - нити зубные
обр.станд. - стандартные образцы лекарственных средств
оподельдок - оподельдоки
основа д/мазей - основа для мазей
основа д/супп. - основа для суппозиториев
паста зубн. - паста зубная
паста орал. - паста для перорального применения
паста стомат. - паста стоматологическая
пастилки детск. - пастилки для детей
пена д/ванн - пена для ванн
пластина п.о. - пластина, покрытая оболочкой
пластина бум. - пластина бумажная
пластина пиротехн. - пластина пиротехническая
пластырь форте - пластырь с максимальной дозировкой/действием
пластырь-ТДТПС - пластырь – трансдермальная терапевтическая проводящая система
пластырь-ТДТС - пластырь – трансдермальная терапевтическая система
пластырь-ТДТС форте - пластырь – трансдермальная терапевтическая система с максимальной дозировкой/действием
пластырь/компл. - пластыри в комплекте
пленка интраваг. - пленка интравагинальная
пленки глазн.лек. - пленки глазные лекарственные
пломб.мат. - пломбировочные материалы
повязка 1-слойн. - повязка однослойная
полоски воск. - полоски восковые
пор. - порошок
пор.д/вдув. - порошок для вдуваний
пор.д/ветерин. - порошок для использования в ветеринарии
пор.д/дез.р-ра - порошок для приготовления дезинфекционного раствора
пор.д/ин. - порошок для приготовления раствора для инъекций
пор.д/ин.в/в - порошок для приготовления инъекционного раствора для в/в введения
пор.д/ин.в/в и в/м - порошок для приготовления раствора для в/в и в/м введения
пор.д/ин.в/в кап. - порошок для приготовления инъекционного раствора для в/в капельного введения
пор.д/ин.в/в стр. - порошок для приготовления инъекционного раствора для в/в струйного введения
пор.д/ин.в/м - порошок для приготовления инъекционного раствора для в/м введения
пор.д/ингал. - порошок для ингаляций/вдыхания
пор.д/ингал.доз. - порошок для ингаляций/вдыхания дозированный
пор.д/инф. - порошок для приготовления инфузионного раствора
пор.д/капель - порошок для приготовления капель
пор.д/капель глазн. - порошок для приготовления глазных капель
пор.д/капель орал.детск. - порошок для приготовления капель для перорального применения для детей
пор.д/маски д/лица - порошок для приготовления маски по уходу за кожей лица
пор.д/р-ра - порошок для приготовления раствора
пор.д/р-ра наружн. - порошок для приготовления раствора для наружного применения
пор.д/р-ра орал. - порошок для приготовления раствора для перорального применения
пор.д/р-ра орал.детск. - порошок для приготовления раствора для перорального применения для детей
пор.д/сиропа - порошок для приготовления сиропа
пор.д/сусп. - порошок для приготовления суспензии
пор.д/сусп.детск. - порошок для приготовления суспензии детской
пор.д/сусп.орал. - порошок для приготовления суспензии для перорального применения
пор.д/сусп.орал.детск. - порошок для приготовления суспензии для перорального применения для детей
пор.д/сусп.орал.форте - порошок для приготовления суспензии для перорального применения с максимальной дозировкой/действием
пор.д/сусп.форте - порошок для приготовления суспензии с максимальной дозировкой/действием
пор.д/чая - порошок для приготовления чая
пор.доз. - порошок дозированный
пор.доз.д/р-ра орал.детск. - порошок дозированный для приготовления раствора для перорального применения для детей
пор.доз.детск. - порошок дозированный детский
пор.зубн. - порошок зубной
пор.лиоф. - порошок лиофилизированный
пор.лиоф.д/ин. - порошок лиофилизированный для приготовления инъекционного раствора
пор.лиоф.д/ингал. - порошок лиофилизированный для ингаляций
пор.лиоф.д/инф. - порошок лиофилизированный для приготовления инфузионного раствора
пор.лиоф.д/р-ра в/в - порошок лиофилизированный для приготовления раствора для в/в введения
пор.лиоф.д/р-ра наз. - порошок лиофилизированный для приготовления раствора для интраназального применения
пор.лиоф.д/р-ра наружн. - порошок лиофилизированный для приготовления раствора для наружного применения
пор.лиоф.д/р-ра орал. - порошок лиофилизированный для приготовления раствора для перорального применения
пор.лиоф.доз. - порошок лиофилизированный дозированный
пор.наружн. - порошок для наружного применения
пор.орал. - порошок для перорального применения
пор.раствор. - порошок растворимый
пор.смачив. - порошок смачивающийся
пор.стер. - порошок стерильный
пор.шип. - порошок для приготовления шипучего напитка
пор.шип.доз. - порошок для приготовления шипучего напитка дозированный
приманка в контейн. - приманка в контейнере
приманка/гран. - приманка гранулированная
присыпка детск. - присыпка детская
р-р - раствор
р-р в/п - раствор для внутриполостного введения
р-р гемоконсерванта - раствор гемоконсерванта
р-р гемоконсерванта/компл. - раствор гемоконсерванта в комплекте
р-р д/диализа - раствор для диализа
р-р д/жестк.конт.линз - раствор для обработки и хранения жестких контактных линз
р-р д/ин. - раствор для инъекций
р-р д/ин.внутриглазн. - раствор для инъекций внутриглазных
р-р д/ин.депо - раствор для инъекций пролонгированного действия
р-р д/ин.изотон. - раствор для инъекций изотонический
р-р д/ин.масл. - раствор для инъекций масляный
р-р д/ин.масл.в/м - раствор для инъекций масляный для внутримышечного введения
р-р д/ин.п/к - раствор для подкожных инъекций
р-р д/ин.спирт. - раствор для инъекций спиртовой
р-р д/ингал. - раствор для ингаляций
р-р д/ингал.детск. - раствор для ингаляций детский
р-р д/ингал.наркоза - раствор для ингаляционного наркоза
р-р д/инф. - раствор для инфузий
р-р д/конт.линз - раствор для обработки и хранения контактных линз
р-р д/мягк.конт.линз - раствор для обработки и хранения мягких контактных линз
р-р д/перитон.диализа - раствор для перитонеального диализа
р-р дез. - раствор дезинфекционный
р-р инсект. - раствор инсектицидный
р-р ирригац. - раствор ирригационный
р-р масл. - раствор масляный
р-р масл.наружн. - раствор масляный для наружного применения
р-р масл.наружн. и д/ингал. - раствор масляный для наружного применения и для ингаляций
р-р масл.орал. - раствор масляный для перорального применения
р-р наружн. - раствор для наружного применения
р-р наружн. и д/ингал. - раствор для наружного применения и для ингаляций
р-р наружн.стер. - раствор для наружного применения стерильный
р-р орал. - раствор для перорального применения
р-р орал. и д/ингал. - раствор для перорального применения и для ингаляций
р-р орал.детск. - раствор для перорального применения детский
р-р рект. - раствор для ректального применения
р-р спирт. - раствор спиртовой
р-р спирт.наружн. - раствор спиртовой для наружного применения
р-р спирт.орал. - раствор спиртовой для перорального применения
р-р стер. - раствор стерильный
р-р стомат. - раствор стоматологический
р-р сублингв. - раствор для сублингвального применения
резин.жев. - резинка жевательная
салф.с дез.р-ром - салфетки, пропитанные дезраствором
салф.стерил. - салфетка стерильная
сбор лек. - сборы лекарственные
сбор лек./брикеты - сбор лекарственный в брикетах
сироп д/новорожд. - сироп для новорожденных
сироп детск. - сироп для детей
сироп форте - сироп с максимальной дозировкой/действием
смесь парогаз. - смесь парогазовая
смесь пиротехн. - смесь пиротехническая
смесь сух. - смесь сухая
спрей доз. - спрей дозированный
спрей наз. - спрей назальный
спрей наз.детск. - спрей назальный для детей
спрей наз.доз. - спрей назальный дозированный
спрей наружн. - спрей для наружного применения
спрей-гель форте - спрей–гель с максимальной дозировкой/действием
субст. - субстанция
субст.-гран. - субстанция–гранулы
субст.-пор. - субстанция–порошок
субст.д/инф. - субстанция для инфузий
субст.жидк. - субстанция жидкая
субст.крист. - субстанция кристаллическая
субст.лиоф. - субстанция лиофилизированная
субст.масл. - субстанция масляная
субст.н/стаб. - субстанция нестабилизированная
субст.стаб. - субстанция стабилизированная
субст.стер. - субстанция стерильная
супп. - суппозитории
супп.ваг. - суппозитории вагинальные
супп.детск. - суппозитории детские
супп.рект. - суппозитории ректальные
супп.рект.д/новорожд. - суппозитории ректальные для новорожденных
супп.рект.детск. - суппозитории ректальные детские
супп.уретр. - суппозитории уретральные
сусп. - суспензия
сусп.глазн. - суспензия глазная
сусп.д/ин. - суспензия для инъекций
сусп.д/ин. и наз. - суспензия для инъекций и интраназального введения
сусп.д/ин.депо - суспензия для инъекций пролонгированного действия
сусп.д/ин.детск. - суспензия для инъекций детская
сусп.д/ин.масл. - суспензия для инъекций масляная
сусп.д/ингал. - суспензия для ингаляций
сусп.интратрахеальн. - суспензия для интратрахеального введения
сусп.интратрахеальн.детск. - суспензия для интратрахеального введения детская
сусп.мк/капс. - суспензия микрокапсулированная
сусп.орал. - суспензия для перорального применения
сусп.орал.детск. - суспензия для перорального применения детская
сусп.орал.доз. - суспензия для перорального применения дозированная
сусп.орал.форте - суспензия для перорального применения с максимальной дозировкой/действием
сусп.рект. - суспензия для ректального введения
сырье д/БАД - сырье для производства биологически активных добавок
табл. - таблетки
табл./комплект - таблетки в комплекте
табл.ваг. - таблетки вагинальные
табл.д/ветерин. - таблетки для применения в ветеринарии
табл.д/имплант. - таблетки для имплантаций
табл.д/капель глазн. - таблетки для приготовления глазных капель
табл.д/пасты - таблетки для приготовления пасты
табл.д/р-ра глазн. - таблетки для приготовления офтальмологического раствора
табл.д/р-ра наружн. - таблетки для приготовления раствора для наружного применения
табл.д/р-ра орал. - таблетки для приготовления раствора для перорального применения
табл.д/рассас. - таблетки для рассасывания
табл.дел. - таблетки делимые
табл.депо - таблетки депо
табл.детск. - таблетки для детей
табл.детск.дел. - таблетки для детей делимые
табл.детск.дисперг.аромат. - таблетки для детей диспергируемые, ароматизированные
табл.детск.раствор. - таблетки для детей растворимые
табл.детск.раствор.аромат. - таблетки для детей растворимые ароматизированные
табл.дисперг. - таблетки диспергируемые
табл.дисперг.форте - таблетки диспергируемые с максимальной дозировкой/действием
табл.жев. - таблетки жевательные
табл.жев.детск. - таблетки жевательные для детей
табл.лингв. - таблетки лингвальные
табл.масса - таблетируемая масса
табл.мите - таблетки с минимальной дозировкой/действием
табл.п.о. - таблетки, покрытые оболочкой (филмтаблетки)
табл.п.о.д/сусп.орал. - таблетки, покрытые оболочкой, для приготовления суспензии для перорального применения
табл.п.о.дел. - таблетки, покрытые оболочкой, делимые
табл.п.о.депо - таблетки, покрытые оболочкой, депо
табл.п.о.детск. - таблетки, покрытые оболочкой, для детей
табл.п.о.мите - таблетки, покрытые оболочкой, с минимальной дозировкой/действием
табл.п.о.пролонг. - таблетки, покрытые оболочкой, пролонгированного действия
табл.п.о.пролонг.мите - таблетки, покрытые оболочкой, пролонгированного действия с минимальной дозировкой/действием
табл.п.о.пролонг.форте - таблетки, покрытые оболочкой, пролонгированного действия с максимальной дозировкой/действием
табл.п.о.раствор./желуд. - таблетки, покрытые оболочкой, растворимые в желудке
табл.п.о.раствор./кишечн. - таблетки, покрытые оболочкой, растворимые в кишечнике
табл.п.о.раствор./кишечн.ретард - таблетки, покрытые оболочкой, растворимые в кишечнике, пролонгированного действия
табл.п.о.ретард - таблетки, покрытые оболочкой, ретард
табл.п.о.форте - таблетки, покрытые оболочкой, с максимальной дозировкой/действием
табл.п.о.шип. - таблетки, покрытые оболочкой, шипучие
табл.пиротехн. - таблетки пиротехнические
табл.пролонг. - таблетки пролонгированного действия
табл.пролонг.дел. - таблетки пролонгированного действия делимые
табл.раствор. - таблетки растворимые
табл.раствор./желуд. - таблетки, растворимые в желудке
табл.раствор./кишечн. - таблетки, растворимые в кишечнике
табл.ретард - таблетки ретард
табл.семи - таблетки со средней дозировкой/действием
табл.суббукк. - таблетки защечные, или суббуккальные
табл.сублингв. - таблетки сублингвальные
табл.ультраретард - таблетки ультраретард
табл.форте - таблетки с максимальной дозировкой/действием
табл.шип. - таблетки для приготовления шипучего напитка
табл.шип.дел. - таблетки для приготовления шипучего напитка делимые
тамп.стомат. - тампоны стоматологические
ТДТПС - трансдермальная терапевтическая проводящая система
ТДТС - трансдермальная терапевтическая система
тоник д/лица - тоник по уходу за кожей лица
трава/брикеты - трава в брикетах
трит. - тритурации
ТС - терапевтические системы
филмтабл. - филмтаблетки
филмтабл.детск. - филмтаблетки детские
филмтабл.форте - филмтаблетки с максимальной дозировкой/действием
цветки/брикеты - цветки в брикетах
чай лек. - чай лекарственный
чай лек.детск. - чай лекарственный детский
шамп. - шампунь
шамп.-кондицион. - шампунь–кондиционер
шамп.косметич. - шампуни косметические
шнур пиротехн. - шнур пиротехнический
щетка зубн. - щетка зубная
экстр. - экстракты
экстр.густ. - экстракт густой
экстр.жидк. - экстракт жидкий
экстр.жидк.д/ин. - экстракт жидкий для инъекций
экстр.жидк.комб. - экстракт жидкий комбинированный
экстр.жидк.орал. - экстракт жидкий для перорального применения
экстр.масл. - экстракт масляный
экстр.масл.наружн. - экстракт масляный для наружного применения
экстр.сух. - экстракт сухой
эл.фумигатор - электрофумигатор
эликсир детск. - эликсир для детей
эмульс. - эмульсия
эмульс.д/ин. - эмульсия для инъекций
эмульс.д/ин.в/в - эмульсия для инъекций внутривенных
эмульс.д/ингал. - эмульсия для ингаляций
эмульс.д/инф. - эмульсия для инфузий
эмульс.инсект. - эмульсия инсектицидная
эмульс.наз. - эмульсия для носа
эмульс.наружн. - эмульсия для наружного применения
эмульс.оральн. - эмульсия для перорального применения

# %% [markdown]
# # OLD

# %% [markdown]
# ## Clusterization with med_dic

# %%
# classification of one-word prodcuts
from libs.cluster import simple
df_final, med_dic = simple(df)

# %%
len(df), len(df_final)

# %% [markdown]
# # ------------------------------------------

# %% [markdown]
# # ------------------------------------------

# %% [markdown]
# # analyze non-matched products

# %%
df_final.head()

# %%
'лопирел' in list(med_dic['name'])

# %%
df.head()

# %%
df_merged = df.merge(df_final, how='left', on='_id')

# %%
df_merged.head()

# %%
df_merged = df_merged[df_merged['len_y'].isna()]

# %%
len(df_merged)

# %%
len(df)

# %%
df_merged.head(5)

# %%
print("SUM OF ALL LOTS:", df['sum'].sum())
print("SUM OF ALL UNCLASSIFIED:", df_merged['sum_x'].sum())
print("PART:", df_merged['sum_x'].sum()/df['sum'].sum())

# %% [markdown]
# # med_dic frequency dictionary

# %%
from collections import defaultdict
med_dic_freq = defaultdict(int)

for key in med_dic['name']:
    med_dic_freq[key] = df['product_name'].apply(lambda x : key in x).sum()

# %%
med_dic_freq_sorted = sorted(med_dic_freq.items(), key=lambda kv: -kv[1])
med_dic_freq_sorted[:200]

# %%
[('п', 71944),
 ('ц', 22922),
 ('дства', 8625),
 ('едства', 8619),
 ('действ', 5499),
 ('лек', 3713),
 ('систем', 3711),
 ('цен', 3222),
 ('гр', 2463),
 ('инг', 2007),
 ('упаковки', 1637),
 ('лекарств', 1421),
 ('фарм', 1374),
 ('ингаляционного', 894),
 ('лп', 852),
 ('прам', 843),
 ('препаратов', 658),
 ('комплекте', 646),
 ('наименован', 331),
 ('действующих', 326),
 ('включая', 276),
 ('шприц', 264),
 ('противосуд', 174),
 ('наркотических', 97),
 ('нейролептические', 87),
 ('вода', 81),
 ('on', 75),
 ('анестезии', 58),
 ('медикаменты', 57),
 ('прочих', 42),
 ('вегетативную', 39),
 ('брал', 39),
 ('риской', 39),
 ('системы', 38),
 ('действующе', 34),
 ('лекарства', 33),
 ('седотивные', 30),
 ('нейролептики', 30),
 ('сильнодействующие', 26),
 ('анальгетики', 25)]

# %% [markdown]
# ### Recursive Levenshtein Function

# %%
from libs.ld import LD

print(LD("Python", "Peithen"))

# %% [markdown]
# ##### Takes too long to execute

# %% [markdown]
# ### Highly Effective Levenstein Function

# %%
from libs.ld import LDfast


print(LDfast("Python", "Peithen"))
# print("The function was called " + str(levenshtein.calls) + " times!")

new_med_dic = set(list(med_dic['name']))
from collections import defaultdict
med_dic_typo = defaultdict(int)

typo_dict = defaultdict(str)
med_dic_list = list(med_dic['name'])
for i in range(len(med_dic_list) - 1):
    if typo_dict[med_dic_list[i]] == '':
        typo_dict[med_dic_list[i]] =med_dic_list[i]
    for j in range(i + 1, len(med_dic_list)):
        if (LDfast(med_dic_list[i], med_dic_list[j]) <= 1):
            med_dic_typo[med_dic_list[i]] += 1
            try:
                print(med_dic_list[j], med_dic_list[i])
                typo_dict[med_dic_list[j]] =med_dic_list[i]
                new_med_dic.remove(med_dic_list[j])
            except KeyError:
                pass 
    if not (i % 120):
        print(i)
        LDfast.cache_clear()

# %%
import pickle

# %%
pickle.dump(typo_dict, open( "typodict.p", "wb" ) )
pickle.dump(new_med_dic, open( "newmeddic.p", "wb" ) )

# %%
typo_dict = pickle.load( open( "typodict.p", "rb" ) )
new_med_dic = pickle.load( open( "newmeddic.p", "rb" ) )

# %%
len(new_med_dic)

# %%
len(med_dic)

# %%
# sorted_typo = sorted(med_dic_typo.items(), key=lambda kv: -kv[1])
# print(sorted_typo)

# %%
print("NUMBER OF TYPOS : ", len(med_dic) - len(new_med_dic))

# %%
type(new_med_dic)

# %% [markdown]
# ## Word2Vec

# %%
from gensim.models import KeyedVectors

# %%
import zipfile
model_file = '180.zip'
with zipfile.ZipFile(model_file, 'r') as archive:
    stream = archive.open('model.bin')
    model = gensim.models.KeyedVectors.load_word2vec_format(stream, binary=True)

# %%
'день_NOUN' in model

# %%
k = 0
for word in new_med_dic:
    if (word + '_NOUN') in model or (word + '_ADJ') in model or (word + '_VERB') in model:
        print(word)
        k += 1
print(k)

# %%
def rm(word):
    new_med_dic.remove(word)
for w in ['масса', 'вода', 'кофеин', 'прочее', 'лирика', 'доставка']:
    rm(w)

# %% [markdown]
# #### Let's try lemmatize new_med_dic entries

# %%
from pymystem3 import Mystem
text = "Красивая мама красиво мыла раму"
m = Mystem()
lemmas = m.lemmatize(text)
print(''.join(lemmas))

# %%
m.lemmatize('медицинские')[0]

# %% [markdown]
# #### takes too much time

# %% [markdown]
# ## New med_dic

# %%
new_med_dic_list = list(new_med_dic)
n = len(new_med_dic_list)
new_med_dic_tuple = [(new_med_dic_list[i], i) for i in range(n)]

# %%
new_med_dic_pd = pd.DataFrame(new_med_dic_tuple, columns = ['name', 'class'], index = [i for i in range(n)])

# %%
### fix typos
def typo_fix(list_of_words):
    new_list = list()
    for w in list_of_words:
        new_list.append(typo_dict[w])
    return new_list

# %%
typo_dict['пирецетам']

# %%
### fix typos
df['name_del'] = df['name_del'].apply(typo_fix)
df_len1=df[df['len']==1]
df_len1['name']=df_len1['name_del'].apply(lambda x: x[0])

df_len1=pd.merge(df_len1, new_med_dic_pd, on='name', how='left')

# classification of more-than-one-word prodcuts w.r.t. one-word-products
df_len2=df[df['len']>1]

def search_list(doc):
    for w in doc:
        ind=[i for i, j in enumerate(new_med_dic_pd['name']) if j == w]    
        if len(ind)>0:
            return new_med_dic_pd.loc[ind[0],'class']
    return 

df_len2['class']=df_len2['name_del'].apply(search_list)
df_len2=pd.merge(df_len2, new_med_dic_pd, on='class', how='left')
# Check classes if needed
#df_len2['class'].isna().sum()
#freqs = Counter(df_len2['class'])
#pop_class=[cl[0] for cl in freqs.most_common()[0:50]]

df_final=pd.concat([df_len1,df_len2])
df_final=df_final[df_final['class'].isna()==0]
df_final['name_del_text']=df_final['name_del'].apply(lambda x: ' ' + ' '.join(x) + ' ')
df_final['number']=df_final['number'].apply(lambda x: x.replace('№',''))
df_final=df_final.drop(['name','name_del','name_word'], axis=1)


import csv
df_final.to_csv('medical_2012_class_new.csv', sep=';',quoting=csv.QUOTE_NONNUMERIC)

# %%
type_dict={'tablet':['таблетки', 'таблетка', 'таб', 'таблет', 'тб', 'тбт', 'табл', 'драже', 'др', 'драж', 'капс', 'капсула', 'капсулы'],
           'cream':['мазь', 'мз', 'мзь', 'эмульс', 'эмульсия'],
           'powder':['пор', 'порошок'],
           'liquid':['рр','рас','раст', 'раств', 'раствор', 'концентрат', 'конц', 'сусп', 'сироп', 'сир'],
           'capsule':['амп', 'ампулы', 'ампула'],
           'spray': ['спрей', 'спр', 'аэр', 'аэрозоль', 'аэроз'],
           'dropley':['капли', 'каплях', 'капл', 'кап']           
           }

types = list(type_dict.keys())

types.append('unknown')

types

# %% [markdown]
# ## Full data

# %%
col_type={'_id': str,
           'cont_num':str,
           'sign_date':str,
           'custom_regnum':str,
           'product_name':str,
           'okdp_code':str,
           'okei_code':str,
           'quantity':float,
           'price':float,
           'sum':float
           }

df = pd.read_csv('datascript/medical_2012_fulldata.csv', sep=';',dtype=col_type)
df = df.dropna()
df = df.drop(['cont_num', 'sign_date', 'custom_regnum', 'okdp_code', 'okei_code'], axis=1)

df['name_norm']=df['product_name'].map(lambda x: re.sub(r'(\D)\.', r'\1. ',x))  # delete symbol point everywhere except for in numbers
df['name_norm']=df['name_norm'].map(lambda x: x.lower())
df['name_norm']=df['name_norm'].map(lambda x: x.replace('№ ','№')) 
df['name_norm']=df['name_norm'].map(lambda x: re.sub(r' n(\d+)| n (\d+)| no(\d+)| no (\d+)', r' №\1',x)) 

mystoplist=[' для ',' д/', ' и ', ' в ',' с ',' у ', ' на ', ' а ',' не ', ' о ']# need also exclude \\dlya
# stoplist = [' ' + stopword + ' ' for stopword in list(stop)]
# mystoplist += stoplist
my_regex = re.compile('|'.join(mystoplist))
df['name_norm']=df['name_norm'].apply(lambda x: my_regex.sub(' ',x)) 
df['name_norm']=df['name_norm'].apply(lambda x: x.replace(':',' ')) 
#punctuation=''.join([sim for sim in list(punctuation) if sim not in ['%',',']]) # list of simbols not to delete

translator = str.maketrans('','',punctuation) 
df['name_norm']=df['name_norm'].map(lambda x: x.translate(translator))

# %%
df_small = pd.read_csv('datascript/medical_2012.csv', sep=';',dtype=col_type)

# %%
len(df_small)

# %%
df['weight']=df['product_name'].apply(weight_mg) + 1000 * df['product_name'].apply(weight_g)

# %%
df['number']=df['name_norm'].apply(prod_number)
# comment it later. it deletes all numbers
df['name_norm']=df['name_norm'].map(lambda x: re.sub('№', '',x))
df['name_norm']=df['name_norm'].map(lambda x: re.sub('\d+', '',x))

df['name_word']=df['name_norm'].map(lambda x : word_tokenize(x))

type_dict={'tablet':['таблетки', 'таблетка', 'таб', 'таблет', 'тб', 'тбт', 'табл', 'драже', 'др', 'драж', 'капс', 'капсула', 'капсулы'],
           'cream':['мазь', 'мз', 'мзь', 'эмульс', 'эмульсия'],
           'powder':['пор', 'порошок'],
           'liquid':['рр','рас','раст', 'раств', 'раствор', 'концентрат', 'конц', 'сусп', 'сироп', 'сир'],
           'capsule':['амп', 'ампулы', 'ампула'],
           'spray': ['спрей', 'спр', 'аэр', 'аэрозоль', 'аэроз'],
           'dropley':['капли', 'каплях', 'капл', 'кап']           
           }
# import pycountry # use it later
countr_list=['австрия','франция','польша','россия','украина', 'латвия', 'мальта', 'хорватия'] # use it later
          

df['type']=df['name_word'].apply(prod_type)


freqs = Counter(df['type'])
freqs.most_common()


df['name_del']=df['name_word'].apply(del_list, dic=type_dict)
#one more round of name_del
df['name_del']=df['name_del'].apply(del_list, dic=type_dict)
df['name_del_text']=df['name_del'].apply(lambda x: ' ' + ' '.join(x) + ' ')
okdp_list=[str(okdp) for okdp in range(2423210,2423220)] # modify for more products

del_dict={'okdp':okdp_list,
          'word1':['средства', 'противосудорожные','действующие', 'центральную', 'нервную', 'снотворные', 'наркоза', 'систему', 'прочие', 'препараты', 'влияющие', ','],
          'word2':['покрытые','внутримышечного','возбуждающие','влияющих','нейроплегические','лекарственный','средствадействующие','лекарственные','лекарственных','н','пролонгированного','наркотические','седативные','','средств','введения','внутривенного','инъекций','оболочкой','по','поб','пленочной','действия','внутрь', 'приема', 'введ', 'поставка'],
          'help':['вв','вм','мгмл','мг','мл','г', '№','мс'], # delete this category later
          'counry': countr_list # delete this category later
          }

df['name_del']=df['name_del'].apply(del_list, dic=del_dict)

df['len']=df['name_del'].apply(lambda x: len(x))
df=df[df['len']>0]

# %%
# classification of one-word prodcuts
df_len1=df[df['len']==1]
df_len1['name']=df_len1['name_del'].apply(lambda x: x[0])

med_dic=df_len1.loc[:,'name']
med_dic=pd.DataFrame(med_dic.drop_duplicates())
med_dic['class']=range(0,len(med_dic['name']))
med_dic['index']=med_dic['class']
med_dic=med_dic.set_index('index')

df_len1=pd.merge(df_len1, med_dic, on='name', how='left')

# classification of more-than-one-word prodcuts w.r.t. one-word-products
df_len2=df[df['len']>1]

def search_list(doc):
    for w in doc:
        ind=[i for i, j in enumerate(med_dic['name']) if j == w]    
        if len(ind)>0:
            return med_dic.loc[ind[0],'class']
    return 

df_len2['class']=df_len2['name_del'].apply(search_list)
df_len2=pd.merge(df_len2, med_dic, on='class', how='left')
# Check classes if needed
#df_len2['class'].isna().sum()
#freqs = Counter(df_len2['class'])
#pop_class=[cl[0] for cl in freqs.most_common()[0:50]]

df_final=pd.concat([df_len1,df_len2])
df_final=df_final[df_final['class'].isna()==0]
df_final['number']=df_final['number'].apply(lambda x: x.replace('№',''))
df_final=df_final.drop(['name','name_del','name_word'], axis=1)


import csv
df_final.to_csv('medical_2012_class_full.csv', sep=';',quoting=csv.QUOTE_NONNUMERIC)
